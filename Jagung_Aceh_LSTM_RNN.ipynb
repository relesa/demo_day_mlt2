# %%
import pandas as pd
df = pd.read_csv('Jagung.csv')

# %%
df.head()
# Out:
#          Provinsi    1993    1994    1995    1996    1997    1998    1999  \
# 0            ACEH   38924   28578   44921   45566   58679   65660   74449
# 1  SUMATERA UTARA  271298  311918  371578  398707  459715  509809  619667
# 2  SUMATERA BARAT   27969   36083   48115   53387   47001   65701   60161
# 3            RIAU   21699   33274   21455   38853   35253   41433   56317
# 4           JAMBI   10206   11337   14213   17895   17764   30320   30533
#
#      2000    2001  ...    2006    2007     2008     2009     2010     2011  \
# 0   36642   51232  ...   96838  125155   112894   137753   167090   168861
# 1  666764  634162  ...  682024   80485  1098969  1166548  1377718  1294645
# 2   56386   48820  ...  202298  223233   351843   404795   354262   471849
# 3   48493   39915  ...   34728    4041    47959    56521    41862    33197
# 4   24875   23975  ...   29288   30028    34616    38169    30691    25521
#
#       2012     2013     2014     2015
# 0   167285   177842   202318   205125
# 1  1347124  1183011  1159795  1519407
# 2   495497   547417   605352   602549
# 3    31433    28052    28651    30870
# 4    25571    25690    43617    51712
#
# [5 rows x 24 columns]

# %%
df_transpose = df.transpose()
df_transpose.head()
# Out:
#              0               1               2      3      4   \
# Provinsi   ACEH  SUMATERA UTARA  SUMATERA BARAT   RIAU  JAMBI
# 1993      38924          271298           27969  21699  10206
# 1994      28578          311918           36083  33274  11337
# 1995      44921          371578           48115  21455  14213
# 1996      45566          398707           53387  38853  17895
#
#                         5         6        7                     8   \
# Provinsi  SUMATERA SELATAN  BENGKULU  LAMPUNG  KEP. BANGKA BELITUNG
# 1993                 48036     36449   579141                     -
# 1994                 36299     32303   563069                     -
# 1995                 82707     52232   843177                     -
# 1996                 85141     53940   938395                     -
#
#                  9   ...              24               25                26  \
# Provinsi  KEP. RIAU  ...  SULAWESI UTARA  SULAWESI TENGAH  SULAWESI SELATAN
# 1993              -  ...          124053            14647            533577
# 1994              -  ...          135693            13716            559093
# 1995              -  ...          164431            25925            738935
# 1996              -  ...          176775            37453            842332
#
#                          27         28              29      30            31  \
# Provinsi  SULAWESI TENGGARA  GORONTALO  SULAWESI BARAT  MALUKU  MALUKU UTARA
# 1993                  81769          -               -   25069             -
# 1994                  73513          -               -   22616             -
# 1995                  79858          -               -   12966             -
# 1996                  83744          -               -   16670             -
#
#                    32     33
# Provinsi  PAPUA BARAT  PAPUA
# 1993                -   4017
# 1994                -   4204
# 1995                -   7627
# 1996                -   8251
#
# [5 rows x 34 columns]

# %%
header=df_transpose.iloc[0]
df2=df_transpose[1:]
df2.columns=header
df2.head()
# Out:
# Provinsi   ACEH SUMATERA UTARA SUMATERA BARAT   RIAU  JAMBI SUMATERA SELATAN  \
# 1993      38924         271298          27969  21699  10206            48036
# 1994      28578         311918          36083  33274  11337            36299
# 1995      44921         371578          48115  21455  14213            82707
# 1996      45566         398707          53387  38853  17895            85141
# 1997      58679         459715          47001  35253  17764           108450
#
# Provinsi BENGKULU  LAMPUNG KEP. BANGKA BELITUNG KEP. RIAU  ... SULAWESI UTARA  \
# 1993        36449   579141                    -         -  ...         124053
# 1994        32303   563069                    -         -  ...         135693
# 1995        52232   843177                    -         -  ...         164431
# 1996        53940   938395                    -         -  ...         176775
# 1997        61081  1080691                    -         -  ...         140473
#
# Provinsi SULAWESI TENGAH SULAWESI SELATAN SULAWESI TENGGARA GORONTALO  \
# 1993               14647           533577             81769         -
# 1994               13716           559093             73513         -
# 1995               25925           738935             79858         -
# 1996               37453           842332             83744         -
# 1997               26986           872070             75882         -
#
# Provinsi SULAWESI BARAT MALUKU MALUKU UTARA PAPUA BARAT PAPUA
# 1993                  -  25069            -           -  4017
# 1994                  -  22616            -           -  4204
# 1995                  -  12966            -           -  7627
# 1996                  -  16670            -           -  8251
# 1997                  -  17101            -           -  9269
#
# [5 rows x 34 columns]

# %%
df2.describe()
# Out:
# Provinsi   ACEH SUMATERA UTARA SUMATERA BARAT   RIAU  JAMBI SUMATERA SELATAN  \
# count        23             23             23     23     23               23
# unique       23             23             23     23     23               23
# top       38924         271298          27969  21699  10206            48036
# freq          1              1              1      1      1                1
#
# Provinsi BENGKULU LAMPUNG KEP. BANGKA BELITUNG KEP. RIAU  ...  SULAWESI UTARA  \
# count          23      23                   23        23  ...              23
# unique         23      23                   16        12  ...              23
# top         36449  579141                    -         -  ...          124053
# freq            1       1                    8        12  ...               1
#
# Provinsi SULAWESI TENGAH SULAWESI SELATAN SULAWESI TENGGARA GORONTALO  \
# count                 23               23                23        23
# unique                23               23                23        16
# top                14647           533577             81769         -
# freq                   1                1                 1         8
#
# Provinsi SULAWESI BARAT MALUKU MALUKU UTARA PAPUA BARAT PAPUA
# count                23     23           23          23    23
# unique               12     23           14          12    23
# top                   -  25069            -           -  4017
# freq                 12      1           10          12     1
#
# [4 rows x 34 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 1993 to 2015
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ACEH                  23 non-null     object
#  1   SUMATERA UTARA        23 non-null     object
#  2   SUMATERA BARAT        23 non-null     object
#  3   RIAU                  23 non-null     object
#  4   JAMBI                 23 non-null     object
#  5   SUMATERA SELATAN      23 non-null     object
#  6   BENGKULU              23 non-null     object
#  7   LAMPUNG               23 non-null     object
#  8   KEP. BANGKA BELITUNG  23 non-null     object
#  9   KEP. RIAU             23 non-null     object
#  10  DKI JAKARTA           23 non-null     object
#  11  JAWA BARAT            23 non-null     object
#  12  JAWA TENGAH           23 non-null     object
#  13  DI YOGYAKARTA         23 non-null     object
#  14  JAWA TIMUR            23 non-null     object
#  15  BANTEN                23 non-null     object
#  16  BALI                  23 non-null     object
#  17  NUSA TENGGARA BARAT   23 non-null     object
#  18  NUSA TENGGARA TIMUR   23 non-null     object
#  19  KALIMANTAN BARAT      23 non-null     object
#  20  KALIMANTAN TENGAH     23 non-null     object
#  21  KALIMANTAN SELATAN    23 non-null     object
#  22  KALIMANTAN TIMUR      23 non-null     object
#  23  KALIMANTAN UTARA      23 non-null     object
#  24  SULAWESI UTARA        23 non-null     object
#  25  SULAWESI TENGAH       23 non-null     object
#  26  SULAWESI SELATAN      23 non-null     object
#  27  SULAWESI TENGGARA     23 non-null     object
#  28  GORONTALO             23 non-null     object
#  29  SULAWESI BARAT        23 non-null     object
#  30  MALUKU                23 non-null     object
#  31  MALUKU UTARA          23 non-null     object
#  32  PAPUA BARAT           23 non-null     object
#  33  PAPUA                 23 non-null     object
# dtypes: object(34)
# memory usage: 6.3+ KB

# %%
df2.dtypes
# Out:
# Provinsi
# ACEH                    object
# SUMATERA UTARA          object
# SUMATERA BARAT          object
# RIAU                    object
# JAMBI                   object
# SUMATERA SELATAN        object
# BENGKULU                object
# LAMPUNG                 object
# KEP. BANGKA BELITUNG    object
# KEP. RIAU               object
# DKI JAKARTA             object
# JAWA BARAT              object
# JAWA TENGAH             object
# DI YOGYAKARTA           object
# JAWA TIMUR              object
# BANTEN                  object
# BALI                    object
# NUSA TENGGARA BARAT     object
# NUSA TENGGARA TIMUR     object
# KALIMANTAN BARAT        object
# KALIMANTAN TENGAH       object
# KALIMANTAN SELATAN      object
# KALIMANTAN TIMUR        object
# KALIMANTAN UTARA        object
# SULAWESI UTARA          object
# SULAWESI TENGAH         object
# SULAWESI SELATAN        object
# SULAWESI TENGGARA       object
# GORONTALO               object
# SULAWESI BARAT          object
# MALUKU                  object
# MALUKU UTARA            object
# PAPUA BARAT             object
# PAPUA                   object
# dtype: object

# %%
df2.shape
# Out:
# (23, 34)

# %%
df2.columns
# Out:
# Index(['ACEH', 'SUMATERA UTARA', 'SUMATERA BARAT', 'RIAU', 'JAMBI',
#        'SUMATERA SELATAN', 'BENGKULU', 'LAMPUNG', 'KEP. BANGKA BELITUNG',
#        'KEP. RIAU', 'DKI JAKARTA', 'JAWA BARAT', 'JAWA TENGAH',
#        'DI YOGYAKARTA', 'JAWA TIMUR', 'BANTEN', 'BALI', 'NUSA TENGGARA BARAT',
#        'NUSA TENGGARA TIMUR', 'KALIMANTAN BARAT', 'KALIMANTAN TENGAH',
#        'KALIMANTAN SELATAN', 'KALIMANTAN TIMUR', 'KALIMANTAN UTARA',
#        'SULAWESI UTARA', 'SULAWESI TENGAH', 'SULAWESI SELATAN',
#        'SULAWESI TENGGARA', 'GORONTALO', 'SULAWESI BARAT', 'MALUKU',
#        'MALUKU UTARA', 'PAPUA BARAT', 'PAPUA'],
#       dtype='object', name='Provinsi')

# %%
df2['ACEH'] = df2['ACEH'].astype(float, errors = 'raise')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 1993 to 2015
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ACEH                  23 non-null     float64
#  1   SUMATERA UTARA        23 non-null     object
#  2   SUMATERA BARAT        23 non-null     object
#  3   RIAU                  23 non-null     object
#  4   JAMBI                 23 non-null     object
#  5   SUMATERA SELATAN      23 non-null     object
#  6   BENGKULU              23 non-null     object
#  7   LAMPUNG               23 non-null     object
#  8   KEP. BANGKA BELITUNG  23 non-null     object
#  9   KEP. RIAU             23 non-null     object
#  10  DKI JAKARTA           23 non-null     object
#  11  JAWA BARAT            23 non-null     object
#  12  JAWA TENGAH           23 non-null     object
#  13  DI YOGYAKARTA         23 non-null     object
#  14  JAWA TIMUR            23 non-null     object
#  15  BANTEN                23 non-null     object
#  16  BALI                  23 non-null     object
#  17  NUSA TENGGARA BARAT   23 non-null     object
#  18  NUSA TENGGARA TIMUR   23 non-null     object
#  19  KALIMANTAN BARAT      23 non-null     object
#  20  KALIMANTAN TENGAH     23 non-null     object
#  21  KALIMANTAN SELATAN    23 non-null     object
#  22  KALIMANTAN TIMUR      23 non-null     object
#  23  KALIMANTAN UTARA      23 non-null     object
#  24  SULAWESI UTARA        23 non-null     object
#  25  SULAWESI TENGAH       23 non-null     object
#  26  SULAWESI SELATAN      23 non-null     object
#  27  SULAWESI TENGGARA     23 non-null     object
#  28  GORONTALO             23 non-null     object
#  29  SULAWESI BARAT        23 non-null     object
#  30  MALUKU                23 non-null     object
#  31  MALUKU UTARA          23 non-null     object
#  32  PAPUA BARAT           23 non-null     object
#  33  PAPUA                 23 non-null     object
# dtypes: float64(1), object(33)
# memory usage: 6.3+ KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.describe()
# Out:
# Provinsi           ACEH
# count         23.000000
# mean      100238.086957
# std        57018.561293
# min        28578.000000
# 25%        54955.500000
# 50%        77747.000000
# 75%       152421.500000
# max       205125.000000

# %%
## finding all columns that have nan:

droping_list_all=[]
for j in range(0,7):
    if not df2.iloc[:, j].notnull().all():
        droping_list_all.append(j)        
        #print(df.iloc[:,j].unique())
droping_list_all
# Out:
# []

# %%
# filling nan with mean in any columns

for j in range(0,1):        
   df2.iloc[:,j]=df2.iloc[:,j].fillna(df2.iloc[:,j].mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
# another sanity check to make sure that there are not more any nan
df2.isnull().sum()
# Out:
# Provinsi
# ACEH                    0
# SUMATERA UTARA          0
# SUMATERA BARAT          0
# RIAU                    0
# JAMBI                   0
# SUMATERA SELATAN        0
# BENGKULU                0
# LAMPUNG                 0
# KEP. BANGKA BELITUNG    0
# KEP. RIAU               0
# DKI JAKARTA             0
# JAWA BARAT              0
# JAWA TENGAH             0
# DI YOGYAKARTA           0
# JAWA TIMUR              0
# BANTEN                  0
# BALI                    0
# NUSA TENGGARA BARAT     0
# NUSA TENGGARA TIMUR     0
# KALIMANTAN BARAT        0
# KALIMANTAN TENGAH       0
# KALIMANTAN SELATAN      0
# KALIMANTAN TIMUR        0
# KALIMANTAN UTARA        0
# SULAWESI UTARA          0
# SULAWESI TENGAH         0
# SULAWESI SELATAN        0
# SULAWESI TENGGARA       0
# GORONTALO               0
# SULAWESI BARAT          0
# MALUKU                  0
# MALUKU UTARA            0
# PAPUA BARAT             0
# PAPUA                   0
# dtype: int64

# %%
import matplotlib.pyplot as plt # this is used for the plot the graph 
df2.ACEH.plot(title='Aceh', color='red') 
plt.tight_layout()
plt.show()

# %%
training_set=df2.iloc[:,1:2].values
print(len(training_set))
# Out:
# 23

# %%
def normalise_windows(window_data):
    # A support function to normalize a dataset
    normalised_data = []
    for window in window_data:
        normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
        normalised_data.append(normalised_window)
    return normalised_data

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set = sc.fit_transform(training_set)

#training_set = normalise_windows(training_set)
print(training_set)
# Out:
# [[0.1326083 ]
#  [0.16083777]
#  [0.20229936]
#  [0.22115306]
#  [0.26355146]
#  [0.29836503]
#  [0.37471246]
#  [0.40744321]
#  [0.38478597]
#  [0.38925529]
#  [0.4217567 ]
#  [0.43926981]
#  [0.45518173]
#  [0.41804837]
#  [0.        ]
#  [0.70781043]
#  [0.75477545]
#  [0.90153115]
#  [0.84379834]
#  [0.8802694 ]
#  [0.76621665]
#  [0.75008235]
#  [1.        ]]

# %%
import numpy as np
seq_len = 3
sequence_length = seq_len + 1
result = []
for index in range(len(training_set) - sequence_length):
    result.append(training_set[index: index + sequence_length])
result=np.array(result)
row = round(0.9 * result.shape[0])
print("training_set=",len(training_set))
print("row=",row)
# Out:
# training_set= 23
# row= 17

# %%
train = result[:int(row), :]
x_train = train[:, :-1]
y_train = train[:, -1]
x_test = result[int(row):, :-1]
y_test = result[int(row):, -1]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1)) 
print(x_train.shape)
print(x_test.shape)
# Out:
# (17, 3, 1)
# (2, 3, 1)

# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras import optimizers

# The LSTM model I would like to test
# Note: replace LSTM with GRU or RNN if you want to try those

model = Sequential()
model.add(LSTM(10, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
#    model.add(LSTM(70))
#    model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

print ('model compiled')

print (model.summary())
# Out:
# model compiled
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10)                480
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the model
history = model.fit(x_train, y_train, batch_size=5, epochs=100, validation_data = (x_test, y_test))

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s 150ms/step - loss: 0.3482 - val_loss: 0.6976
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3272 - val_loss: 0.6548
# Epoch 3/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3077 - val_loss: 0.6128
# Epoch 4/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2962 - val_loss: 0.5742
# Epoch 5/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2675 - val_loss: 0.5385
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2661 - val_loss: 0.5041
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2306 - val_loss: 0.4706
# Epoch 8/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2101 - val_loss: 0.4390
# Epoch 9/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2162 - val_loss: 0.4095
# Epoch 10/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1961 - val_loss: 0.3812
# Epoch 11/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1713 - val_loss: 0.3530
# Epoch 12/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1755 - val_loss: 0.3252
# Epoch 13/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1869 - val_loss: 0.2986
# Epoch 14/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1612 - val_loss: 0.2742
# Epoch 15/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1456 - val_loss: 0.2516
# Epoch 16/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1442 - val_loss: 0.2305
# Epoch 17/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1147 - val_loss: 0.2106
# Epoch 18/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1121 - val_loss: 0.1921
# Epoch 19/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0947 - val_loss: 0.1741
# Epoch 20/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1148 - val_loss: 0.1575
# Epoch 21/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0750 - val_loss: 0.1412
# Epoch 22/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1043 - val_loss: 0.1262
# Epoch 23/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0829 - val_loss: 0.1118
# Epoch 24/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0735 - val_loss: 0.0990
# Epoch 25/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1032 - val_loss: 0.0871
# Epoch 26/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0572 - val_loss: 0.0770
# Epoch 27/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0788 - val_loss: 0.0688
# Epoch 28/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0655 - val_loss: 0.0616
# Epoch 29/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0938 - val_loss: 0.0548
# Epoch 30/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0695 - val_loss: 0.0499
# Epoch 31/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0760 - val_loss: 0.0444
# Epoch 32/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0491 - val_loss: 0.0388
# Epoch 33/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0446 - val_loss: 0.0342
# Epoch 34/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0509 - val_loss: 0.0308
# Epoch 35/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0446 - val_loss: 0.0279
# Epoch 36/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0689 - val_loss: 0.0255
# Epoch 37/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0621 - val_loss: 0.0235
# Epoch 38/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0481 - val_loss: 0.0213
# Epoch 39/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0605 - val_loss: 0.0198
# Epoch 40/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0687 - val_loss: 0.0175
# Epoch 41/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0540 - val_loss: 0.0156
# Epoch 42/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0555 - val_loss: 0.0136
# Epoch 43/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0550 - val_loss: 0.0120
# Epoch 44/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0686 - val_loss: 0.0116
# Epoch 45/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0535 - val_loss: 0.0110
# Epoch 46/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0374 - val_loss: 0.0105
# Epoch 47/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0560 - val_loss: 0.0099
# Epoch 48/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0675 - val_loss: 0.0101
# Epoch 49/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0532 - val_loss: 0.0100
# Epoch 50/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0452 - val_loss: 0.0093
# Epoch 51/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0397 - val_loss: 0.0092
# Epoch 52/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0472 - val_loss: 0.0091
# Epoch 53/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0629 - val_loss: 0.0093
# Epoch 54/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0513 - val_loss: 0.0100
# Epoch 55/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0554 - val_loss: 0.0101
# Epoch 56/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0632 - val_loss: 0.0102
# Epoch 57/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0423 - val_loss: 0.0102
# Epoch 58/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0373 - val_loss: 0.0099
# Epoch 59/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0432 - val_loss: 0.0095
# Epoch 60/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0566 - val_loss: 0.0097
# Epoch 61/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0426 - val_loss: 0.0088
# Epoch 62/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0543 - val_loss: 0.0085
# Epoch 63/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0450 - val_loss: 0.0087
# Epoch 64/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0575 - val_loss: 0.0081
# Epoch 65/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0488 - val_loss: 0.0074
# Epoch 66/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0492 - val_loss: 0.0070
# Epoch 67/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0619 - val_loss: 0.0068
# Epoch 68/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0637 - val_loss: 0.0065
# Epoch 69/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0356 - val_loss: 0.0058
# Epoch 70/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0609 - val_loss: 0.0055
# Epoch 71/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0587 - val_loss: 0.0055
# Epoch 72/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0369 - val_loss: 0.0057
# Epoch 73/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0574 - val_loss: 0.0063
# Epoch 74/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0530 - val_loss: 0.0066
# Epoch 75/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0405 - val_loss: 0.0065
# Epoch 76/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0703 - val_loss: 0.0063
# Epoch 77/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0441 - val_loss: 0.0064
# Epoch 78/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0726 - val_loss: 0.0066
# Epoch 79/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0457 - val_loss: 0.0073
# Epoch 80/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0541 - val_loss: 0.0075
# Epoch 81/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0313 - val_loss: 0.0071
# Epoch 82/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0432 - val_loss: 0.0069
# Epoch 83/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0460 - val_loss: 0.0064
# Epoch 84/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0334 - val_loss: 0.0062
# Epoch 85/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0420 - val_loss: 0.0061
# Epoch 86/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0508 - val_loss: 0.0054
# Epoch 87/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0503 - val_loss: 0.0050
# Epoch 88/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0831 - val_loss: 0.0044
# Epoch 89/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0570 - val_loss: 0.0040
# Epoch 90/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0482 - val_loss: 0.0036
# Epoch 91/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0548 - val_loss: 0.0032
# Epoch 92/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0324 - val_loss: 0.0026
# Epoch 93/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0373 - val_loss: 0.0021
# Epoch 94/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0609 - val_loss: 0.0017
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0375 - val_loss: 0.0015
# Epoch 96/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0431 - val_loss: 0.0014
# Epoch 97/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0470 - val_loss: 0.0012
# Epoch 98/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0394 - val_loss: 0.0013
# Epoch 99/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0613 - val_loss: 0.0015
# Epoch 100/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0349 - val_loss: 0.0016

# %%
def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[np.newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

def plot_results(predicted_data, true_data): 
    fig = plt.figure(facecolor='white') 
    ax = fig.add_subplot(111) 
    ax.plot(true_data, label='True Data') 
    plt.plot(predicted_data, label='Prediction') 
    plt.legend() 
    plt.show() 

predictions= predict_sequence_full(model, x_test, seq_len)
plot_results(predictions,y_test)

# %%
# calculate RMSE
from sklearn.metrics import mean_squared_error,r2_score

mse = mean_squared_error(predictions, y_test)
rmse = np.sqrt(mean_squared_error(predictions, y_test))
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test MSE: 0.002
# Test RMSE: 0.043

# %%
from keras.layers.recurrent import SimpleRNN
# The RNN model I would like to test

model = Sequential()
model.add(SimpleRNN(10, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
#    model.add(LSTM(70))
#    model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

print ('model compiled')

print (model.summary())
# Out:
# model compiled
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 10)                120
#
#  dropout_2 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the model
history = model.fit(x_train, y_train, batch_size=5, epochs=100, validation_data = (x_test, y_test))

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 79ms/step - loss: 0.0766 - val_loss: 0.0628
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0614 - val_loss: 0.0274
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1046 - val_loss: 0.0076
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1199 - val_loss: 5.2197e-04
# Epoch 5/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0710 - val_loss: 6.0577e-04
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0443 - val_loss: 0.0019
# Epoch 7/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0657 - val_loss: 0.0046
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0530 - val_loss: 0.0061
# Epoch 9/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0850 - val_loss: 0.0051
# Epoch 10/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0553 - val_loss: 0.0028
# Epoch 11/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0858 - val_loss: 0.0017
# Epoch 12/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0836 - val_loss: 0.0017
# Epoch 13/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0687 - val_loss: 0.0015
# Epoch 14/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0333 - val_loss: 0.0011
# Epoch 15/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0835 - val_loss: 8.0105e-04
# Epoch 16/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0526 - val_loss: 9.7339e-04
# Epoch 17/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0715 - val_loss: 2.0631e-04
# Epoch 18/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0601 - val_loss: 1.5756e-04
# Epoch 19/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0386 - val_loss: 5.7894e-04
# Epoch 20/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0288 - val_loss: 0.0010
# Epoch 21/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0348 - val_loss: 9.2954e-04
# Epoch 22/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0908 - val_loss: 2.6055e-04
# Epoch 23/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0434 - val_loss: 1.1712e-04
# Epoch 24/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0509 - val_loss: 1.1970e-04
# Epoch 25/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0819 - val_loss: 4.6704e-05
# Epoch 26/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0597 - val_loss: 1.2746e-05
# Epoch 27/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0565 - val_loss: 1.6282e-04
# Epoch 28/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0696 - val_loss: 9.1798e-04
# Epoch 29/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0236 - val_loss: 0.0018
# Epoch 30/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0666 - val_loss: 0.0014
# Epoch 31/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0690 - val_loss: 0.0014
# Epoch 32/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0568 - val_loss: 6.1762e-04
# Epoch 33/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1185 - val_loss: 6.3086e-05
# Epoch 34/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0470 - val_loss: 1.3408e-05
# Epoch 35/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0316 - val_loss: 3.9724e-05
# Epoch 36/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0369 - val_loss: 1.9218e-05
# Epoch 37/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0345 - val_loss: 2.5802e-04
# Epoch 38/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0505 - val_loss: 4.4831e-04
# Epoch 39/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0377 - val_loss: 0.0013
# Epoch 40/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0351 - val_loss: 0.0015
# Epoch 41/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0399 - val_loss: 0.0014
# Epoch 42/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0505 - val_loss: 0.0011
# Epoch 43/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0413 - val_loss: 2.1807e-04
# Epoch 44/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0294 - val_loss: 1.4879e-04
# Epoch 45/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0381 - val_loss: 6.6373e-04
# Epoch 46/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0492 - val_loss: 9.3422e-04
# Epoch 47/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0633 - val_loss: 3.6835e-04
# Epoch 48/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0202 - val_loss: 2.6182e-05
# Epoch 49/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0587 - val_loss: 8.9133e-05
# Epoch 50/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0445 - val_loss: 2.3704e-05
# Epoch 51/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0639 - val_loss: 4.6533e-05
# Epoch 52/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0528 - val_loss: 1.6299e-04
# Epoch 53/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0933 - val_loss: 0.0011
# Epoch 54/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0396 - val_loss: 5.7600e-04
# Epoch 55/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0480 - val_loss: 3.8281e-05
# Epoch 56/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0741 - val_loss: 2.8228e-05
# Epoch 57/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0362 - val_loss: 1.0349e-04
# Epoch 58/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0600 - val_loss: 2.7577e-04
# Epoch 59/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0675 - val_loss: 3.6606e-04
# Epoch 60/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0399 - val_loss: 4.2070e-04
# Epoch 61/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0462 - val_loss: 8.7961e-04
# Epoch 62/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0542 - val_loss: 0.0018
# Epoch 63/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0349 - val_loss: 0.0024
# Epoch 64/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0277 - val_loss: 0.0021
# Epoch 65/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0483 - val_loss: 0.0018
# Epoch 66/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0381 - val_loss: 0.0019
# Epoch 67/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0490 - val_loss: 0.0020
# Epoch 68/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0471 - val_loss: 9.1466e-04
# Epoch 69/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0360 - val_loss: 6.3070e-04
# Epoch 70/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0404 - val_loss: 8.9074e-04
# Epoch 71/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0478 - val_loss: 8.0429e-04
# Epoch 72/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0198 - val_loss: 7.8421e-04
# Epoch 73/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0590 - val_loss: 2.6937e-04
# Epoch 74/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0591 - val_loss: 2.9160e-04
# Epoch 75/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0370 - val_loss: 1.2953e-04
# Epoch 76/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0417 - val_loss: 6.2939e-05
# Epoch 77/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0401 - val_loss: 8.9631e-05
# Epoch 78/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0361 - val_loss: 3.5918e-04
# Epoch 79/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0558 - val_loss: 0.0011
# Epoch 80/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0437 - val_loss: 7.1629e-04
# Epoch 81/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0789 - val_loss: 9.2005e-05
# Epoch 82/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0514 - val_loss: 6.1126e-04
# Epoch 83/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0312 - val_loss: 0.0013
# Epoch 84/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0535 - val_loss: 0.0014
# Epoch 85/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0570 - val_loss: 0.0014
# Epoch 86/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0522 - val_loss: 0.0012
# Epoch 87/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0698 - val_loss: 9.4662e-04
# Epoch 88/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0354 - val_loss: 0.0011
# Epoch 89/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0533 - val_loss: 0.0015
# Epoch 90/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0467 - val_loss: 0.0014
# Epoch 91/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0332 - val_loss: 0.0018
# Epoch 92/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0710 - val_loss: 0.0028
# Epoch 93/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0486 - val_loss: 0.0020
# Epoch 94/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0236 - val_loss: 0.0015
# Epoch 95/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0356 - val_loss: 6.8095e-04
# Epoch 96/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0459 - val_loss: 3.2447e-04
# Epoch 97/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0346 - val_loss: 2.5270e-04
# Epoch 98/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0423 - val_loss: 1.6860e-04
# Epoch 99/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0435 - val_loss: 1.6060e-04
# Epoch 100/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0332 - val_loss: 1.9022e-04

# %%
predictions= predict_sequence_full(model, x_test, seq_len)
plot_results(predictions,y_test)

# %%
# calculate RMSE
from sklearn.metrics import mean_squared_error,r2_score

mse = mean_squared_error(predictions, y_test)
rmse = np.sqrt(mean_squared_error(predictions, y_test))
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test MSE: 0.000
# Test RMSE: 0.015
