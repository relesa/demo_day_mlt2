# %% [markdown]
# Import

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Import Data Set

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d3d408ea-2044-4cf6-aff6-be0657855775" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3d408ea-2044-4cf6-aff6-be0657855775">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Padi.csv to Padi.csv

# %%
import pandas as pd
import io
 
df = pd.read_csv(io.BytesIO(uploaded['Padi.csv']))
print(df)
# Out:
#                 Provinsi      1993     1994      1995      1996      1997  \
# 0                   ACEH   1299699  1329536   1368074   1419128   1382905
# 1         SUMATERA UTARA   2918152  3079960   3134533   3136760   3212208
# 2         SUMATERA BARAT   1806424  1747543   1829192   1971180   1787719
# 3                   RIAU    436297   445361    458756    461905    416135
# 4                  JAMBI    607529   564722    593502    657650    572269
# 5       SUMATERA SELATAN   1409559  1347611   1557944   1666591   1577398
# 6               BENGKULU    356709   334232    377337    396977    382123
# 7                LAMPUNG   1646900  1615751   1943709   1971740   1753656
# 8   KEP. BANGKA BELITUNG         -        -         -         -         -
# 9              KEP. RIAU         -        -         -         -         -
# 10           DKI JAKARTA     28488    22965     19309     17347     16491
# 11            JAWA BARAT  10820862  9860375  10722717  10747659  10352650
# 12           JAWA TENGAH   8174897  7722611   8198084   8359105   8328756
# 13         DI YOGYAKARTA    644642   643266    642120    661179    647198
# 14            JAWA TIMUR   8627784  8296348   8572668   8628766   8533839
# 15                BANTEN         -        -         -         -         -
# 16                  BALI    837054   801495    831172    840564    791196
# 17   NUSA TENGGARA BARAT   1186926  1187513   1235882   1291140   1294483
# 18   NUSA TENGGARA TIMUR    381915   410757    419929    465534    463154
# 19      KALIMANTAN BARAT    770136   766542    827669    838563    829106
# 20     KALIMANTAN TENGAH    313729   362497    378129    395896    379548
# 21    KALIMANTAN SELATAN   1138140  1123082   1189062   1214038   1203184
# 22      KALIMANTAN TIMUR    254730   308154    362193    408969    411745
# 23      KALIMANTAN UTARA         -        -         -         -         -
# 24        SULAWESI UTARA    393314   391186    397113    475018    393593
# 25       SULAWESI TENGAH    462505   449185    539648    583879    523682
# 26      SULAWESI SELATAN   3303591  3467984   3727081   4052228   3769450
# 27     SULAWESI TENGGARA    220919   246936    287355    305940    260334
# 28             GORONTALO         -        -         -         -         -
# 29        SULAWESI BARAT         -        -         -         -         -
# 30                MALUKU     51330    29904     35151     31240     17878
# 31          MALUKU UTARA         -        -         -         -         -
# 32           PAPUA BARAT         -        -         -         -         -
# 33                 PAPUA     37090    42864     49115     49903     38386
#
#        1998     1999      2000     2001  ...     2006     2007      2008  \
# 0   1486909  1478712   1404580  1246614  ...  1350748  1533369   1402287
# 1   3321049  3451430   3514253  3291515  ...  3007636  3265834   3340794
# 2   1807622  1897678   1759059  1668955  ...  1889489  1938120   1965634
# 3    370124   461630    431351   413391  ...    42938   490087    494260
# 4    550277   553641    536779   556564  ...   544597    58663    581704
# 5   1931505  1789961   1863643  1723433  ...  2456251  2753044   2971286
# 6    375533   381577    362979   376973  ...   378377   470469    484900
# 7   1975700  1801422   1946406  1992726  ...  2129914  2308404   2341075
# 8         -        -         -    16430  ...    16506     2439     15079
# 9         -        -         -        -  ...      332      343       404
# 10    14488    15813     16275    16886  ...     6197     8002      8352
# 11  9795638  9993014  10749868  9237593  ...  9418572  9914019  10111069
# 12  8594043  8345854   8475412  8289927  ...  8729291  8616855   9136405
# 13   621605   612393    654289   661802  ...   708163   709294    798232
# 14  8691519  8956196   9224353  8672791  ...  9346947  9402029  10474773
# 15        -        -         -  1433397  ...  1751468  1816140   1818166
# 16   825934   836055    826838   789232  ...   840891   839775    840465
# 17  1344717  1396077   1488191  1458616  ...  1552627  1526347   1750677
# 18   432219   473000    461413   448001  ...   511911   505628    577895
# 19   827499   969658    903191   941630  ...  1107661  1225259   1321443
# 20   277141   306567    362630   360084  ...   491712   562473    522732
# 21  1052481  1380443   1332364  1406070  ...  1636840  1953868   1954284
# 22   170256   409884    401955   366708  ...   541171   567501    586031
# 23        -        -         -        -  ...        -        -         -
# 24   302890   367804    514477   310802  ...   454902    49495    520193
# 25   494401   639739    576933   520642  ...   739777   857508    985418
# 26  3560834  3870842   3658836  3728736  ...  3365509  3635139   4083356
# 27   276913   346214    314955   263477  ...   349429   423316    405256
# 28        -        -         -   158871  ...   192583   200421    237873
# 29        -        -         -        -  ...   301616   312676    343221
# 30    39483    48857     36288    33885  ...    49833    57132     75826
# 31        -        -         -        -  ...    59215    48531     51599
# 32        -        -         -        -  ...    27073    28204     39537
# 33    59064    81926     81534    75031  ...    68319    81678     85699
#
#         2009      2010      2011      2012      2013      2014      2015
# 0    1556858   1582393   1772962   1788738   1956940   1820062   2331046
# 1    3527899   3582302   3607403   3715514   3727249   3631039   4044829
# 2    2105790   2211248   2279602   2368390   2430384   2519020   2550609
# 3     531429    574864    535788    512152    434144    385475    393917
# 4     644947    628828    646641    625164    664535    664720    541486
# 5    3125236   3272451   3384670   3295247   3676723   3670435   4247922
# 6     510160    516869    502552    581910    622832    593194    578654
# 7    2673844   2807676   2940795   3101455   3207002   3320064   3641895
# 8      19864     22259     15211     22395     28480     23481     27068
# 9        430      1246      1223      1323      1370      1403       959
# 10     11013     11164      9516     11044     10268      7541      6361
# 11  11322681  11737070  11633891  11271861  12083162  11644899  11373144
# 12   9600415  10110830   9391959  10232934  10344816   9648104  11301422
# 13    837930    823887    842934    946224    921824    919573    945136
# 14  11259085  11643773  10576543  12198707  12049342  12397049  13154967
# 15   1849007   2048047   1949714   1865893   2083608   2045883   2188996
# 16    878764    869161    858316    865553    882092    857944    853710
# 17   1870775   1774499   2067137   2114231   2193698   2116637   2417392
# 18    607359    555493    591371    698566    729666    825728    948088
# 19   1300798   1343888   1372988   1300100   1441876   1372695   1275707
# 20    578761    650416    610236    755507    812652    838207    893202
# 21   1956993   1842089   2038309   2086221   2031029   2094590   2140276
# 22    555560    588879    552616    561959    439439    426567    408782
# 23         -         -         -         -    124724    115620    112102
# 24    549087    584030    596223    615062    638373    637927    674169
# 25    953396    957108   1041789   1024316   1031364   1022054   1015368
# 26   4324178   4382443   4511705   5003011   5035830   5426097   5471806
# 27    407367    454644    491567    516291    561361    657617    660720
# 28    256934    253563    273921    245786    295913    314704    331220
# 29    310706    362900    365683    412338    445030    449621    461844
# 30     89875     83109     87468     84271    101835    102761    117791
# 31     46253     55401     61430     65686     72445     72074     75265
# 32     36985     34254     29304     30245     29912     27665     30219
# 33     98511    102610    115437    138032    169791    196015    181769
#
# [34 rows x 24 columns]

# %% [markdown]
# Menampilkan Data Set Padi dalam bentuk Tabel

# %%
import pandas as pd
df = pd.read_csv('Padi.csv')
df.head()
# Out:
#          Provinsi     1993     1994     1995     1996     1997     1998  \
# 0            ACEH  1299699  1329536  1368074  1419128  1382905  1486909
# 1  SUMATERA UTARA  2918152  3079960  3134533  3136760  3212208  3321049
# 2  SUMATERA BARAT  1806424  1747543  1829192  1971180  1787719  1807622
# 3            RIAU   436297   445361   458756   461905   416135   370124
# 4           JAMBI   607529   564722   593502   657650   572269   550277
#
#       1999     2000     2001  ...     2006     2007     2008     2009  \
# 0  1478712  1404580  1246614  ...  1350748  1533369  1402287  1556858
# 1  3451430  3514253  3291515  ...  3007636  3265834  3340794  3527899
# 2  1897678  1759059  1668955  ...  1889489  1938120  1965634  2105790
# 3   461630   431351   413391  ...    42938   490087   494260   531429
# 4   553641   536779   556564  ...   544597    58663   581704   644947
#
#       2010     2011     2012     2013     2014     2015
# 0  1582393  1772962  1788738  1956940  1820062  2331046
# 1  3582302  3607403  3715514  3727249  3631039  4044829
# 2  2211248  2279602  2368390  2430384  2519020  2550609
# 3   574864   535788   512152   434144   385475   393917
# 4   628828   646641   625164   664535   664720   541486
#
# [5 rows x 24 columns]
# Warning: Total number of columns (24) exceeds max_columns (20) limiting to first (20) columns.

# %% [markdown]
# Transpose Tabel

# %%
df_transpose = df.transpose()
df_transpose.head()
# Out:
#                0               1               2       3       4   \
# Provinsi     ACEH  SUMATERA UTARA  SUMATERA BARAT    RIAU   JAMBI
# 1993      1299699         2918152         1806424  436297  607529
# 1994      1329536         3079960         1747543  445361  564722
# 1995      1368074         3134533         1829192  458756  593502
# 1996      1419128         3136760         1971180  461905  657650
#
#                         5         6        7                     8   \
# Provinsi  SUMATERA SELATAN  BENGKULU  LAMPUNG  KEP. BANGKA BELITUNG
# 1993               1409559    356709  1646900                     -
# 1994               1347611    334232  1615751                     -
# 1995               1557944    377337  1943709                     -
# 1996               1666591    396977  1971740                     -
#
#                  9   ...              24               25                26  \
# Provinsi  KEP. RIAU  ...  SULAWESI UTARA  SULAWESI TENGAH  SULAWESI SELATAN
# 1993              -  ...          393314           462505           3303591
# 1994              -  ...          391186           449185           3467984
# 1995              -  ...          397113           539648           3727081
# 1996              -  ...          475018           583879           4052228
#
#                          27         28              29      30            31  \
# Provinsi  SULAWESI TENGGARA  GORONTALO  SULAWESI BARAT  MALUKU  MALUKU UTARA
# 1993                 220919          -               -   51330             -
# 1994                 246936          -               -   29904             -
# 1995                 287355          -               -   35151             -
# 1996                 305940          -               -   31240             -
#
#                    32     33
# Provinsi  PAPUA BARAT  PAPUA
# 1993                -  37090
# 1994                -  42864
# 1995                -  49115
# 1996                -  49903
#
# [5 rows x 34 columns]

# %%
header=df_transpose.iloc[0]
df2=df_transpose[1:]
df2.columns=header
df2.head()
# Out:
# Provinsi     ACEH SUMATERA UTARA SUMATERA BARAT    RIAU   JAMBI  \
# 1993      1299699        2918152        1806424  436297  607529
# 1994      1329536        3079960        1747543  445361  564722
# 1995      1368074        3134533        1829192  458756  593502
# 1996      1419128        3136760        1971180  461905  657650
# 1997      1382905        3212208        1787719  416135  572269
#
# Provinsi SUMATERA SELATAN BENGKULU  LAMPUNG KEP. BANGKA BELITUNG KEP. RIAU  \
# 1993              1409559   356709  1646900                    -         -
# 1994              1347611   334232  1615751                    -         -
# 1995              1557944   377337  1943709                    -         -
# 1996              1666591   396977  1971740                    -         -
# 1997              1577398   382123  1753656                    -         -
#
# Provinsi  ... SULAWESI UTARA SULAWESI TENGAH SULAWESI SELATAN  \
# 1993      ...         393314          462505          3303591
# 1994      ...         391186          449185          3467984
# 1995      ...         397113          539648          3727081
# 1996      ...         475018          583879          4052228
# 1997      ...         393593          523682          3769450
#
# Provinsi SULAWESI TENGGARA GORONTALO SULAWESI BARAT MALUKU MALUKU UTARA  \
# 1993                220919         -              -  51330            -
# 1994                246936         -              -  29904            -
# 1995                287355         -              -  35151            -
# 1996                305940         -              -  31240            -
# 1997                260334         -              -  17878            -
#
# Provinsi PAPUA BARAT  PAPUA
# 1993               -  37090
# 1994               -  42864
# 1995               -  49115
# 1996               -  49903
# 1997               -  38386
#
# [5 rows x 34 columns]

# %% [markdown]
# Deskripsi Data Set

# %%
df2.describe()
# Out:
# Provinsi     ACEH SUMATERA UTARA SUMATERA BARAT    RIAU   JAMBI  \
# count          23             23             23      23      23
# unique         23             23             23      23      23
# top       1299699        2918152        1806424  436297  607529
# freq            1              1              1       1       1
#
# Provinsi SUMATERA SELATAN BENGKULU  LAMPUNG KEP. BANGKA BELITUNG KEP. RIAU  \
# count                  23       23       23                   23        23
# unique                 23       23       23                   16        12
# top               1409559   356709  1646900                    -         -
# freq                    1        1        1                    8        12
#
# Provinsi  ... SULAWESI UTARA SULAWESI TENGAH SULAWESI SELATAN  \
# count     ...             23              23               23
# unique    ...             23              23               23
# top       ...         393314          462505          3303591
# freq      ...              1               1                1
#
# Provinsi SULAWESI TENGGARA GORONTALO SULAWESI BARAT MALUKU MALUKU UTARA  \
# count                   23        23             23     23           23
# unique                  23        16             12     23           14
# top                 220919         -              -  51330            -
# freq                     1         8             12      1           10
#
# Provinsi PAPUA BARAT  PAPUA
# count             23     23
# unique            12     23
# top                -  37090
# freq              12      1
#
# [4 rows x 34 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 1993 to 2015
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ACEH                  23 non-null     object
#  1   SUMATERA UTARA        23 non-null     object
#  2   SUMATERA BARAT        23 non-null     object
#  3   RIAU                  23 non-null     object
#  4   JAMBI                 23 non-null     object
#  5   SUMATERA SELATAN      23 non-null     object
#  6   BENGKULU              23 non-null     object
#  7   LAMPUNG               23 non-null     object
#  8   KEP. BANGKA BELITUNG  23 non-null     object
#  9   KEP. RIAU             23 non-null     object
#  10  DKI JAKARTA           23 non-null     object
#  11  JAWA BARAT            23 non-null     object
#  12  JAWA TENGAH           23 non-null     object
#  13  DI YOGYAKARTA         23 non-null     object
#  14  JAWA TIMUR            23 non-null     object
#  15  BANTEN                23 non-null     object
#  16  BALI                  23 non-null     object
#  17  NUSA TENGGARA BARAT   23 non-null     object
#  18  NUSA TENGGARA TIMUR   23 non-null     object
#  19  KALIMANTAN BARAT      23 non-null     object
#  20  KALIMANTAN TENGAH     23 non-null     object
#  21  KALIMANTAN SELATAN    23 non-null     object
#  22  KALIMANTAN TIMUR      23 non-null     object
#  23  KALIMANTAN UTARA      23 non-null     object
#  24  SULAWESI UTARA        23 non-null     object
#  25  SULAWESI TENGAH       23 non-null     object
#  26  SULAWESI SELATAN      23 non-null     object
#  27  SULAWESI TENGGARA     23 non-null     object
#  28  GORONTALO             23 non-null     object
#  29  SULAWESI BARAT        23 non-null     object
#  30  MALUKU                23 non-null     object
#  31  MALUKU UTARA          23 non-null     object
#  32  PAPUA BARAT           23 non-null     object
#  33  PAPUA                 23 non-null     object
# dtypes: object(34)
# memory usage: 6.3+ KB

# %%
df2.dtypes
# Out:
# Provinsi
# ACEH                    object
# SUMATERA UTARA          object
# SUMATERA BARAT          object
# RIAU                    object
# JAMBI                   object
# SUMATERA SELATAN        object
# BENGKULU                object
# LAMPUNG                 object
# KEP. BANGKA BELITUNG    object
# KEP. RIAU               object
# DKI JAKARTA             object
# JAWA BARAT              object
# JAWA TENGAH             object
# DI YOGYAKARTA           object
# JAWA TIMUR              object
# BANTEN                  object
# BALI                    object
# NUSA TENGGARA BARAT     object
# NUSA TENGGARA TIMUR     object
# KALIMANTAN BARAT        object
# KALIMANTAN TENGAH       object
# KALIMANTAN SELATAN      object
# KALIMANTAN TIMUR        object
# KALIMANTAN UTARA        object
# SULAWESI UTARA          object
# SULAWESI TENGAH         object
# SULAWESI SELATAN        object
# SULAWESI TENGGARA       object
# GORONTALO               object
# SULAWESI BARAT          object
# MALUKU                  object
# MALUKU UTARA            object
# PAPUA BARAT             object
# PAPUA                   object
# dtype: object

# %%
df2.shape
# Out:
# (23, 34)

# %%
df2.columns
# Out:
# Index(['ACEH', 'SUMATERA UTARA', 'SUMATERA BARAT', 'RIAU', 'JAMBI',
#        'SUMATERA SELATAN', 'BENGKULU', 'LAMPUNG', 'KEP. BANGKA BELITUNG',
#        'KEP. RIAU', 'DKI JAKARTA', 'JAWA BARAT', 'JAWA TENGAH',
#        'DI YOGYAKARTA', 'JAWA TIMUR', 'BANTEN', 'BALI', 'NUSA TENGGARA BARAT',
#        'NUSA TENGGARA TIMUR', 'KALIMANTAN BARAT', 'KALIMANTAN TENGAH',
#        'KALIMANTAN SELATAN', 'KALIMANTAN TIMUR', 'KALIMANTAN UTARA',
#        'SULAWESI UTARA', 'SULAWESI TENGAH', 'SULAWESI SELATAN',
#        'SULAWESI TENGGARA', 'GORONTALO', 'SULAWESI BARAT', 'MALUKU',
#        'MALUKU UTARA', 'PAPUA BARAT', 'PAPUA'],
#       dtype='object', name='Provinsi')

# %% [markdown]
# **ACEH**

# %%
df2['ACEH'] = df2['ACEH'].astype(float, errors = 'raise')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 1993 to 2015
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ACEH                  23 non-null     float64
#  1   SUMATERA UTARA        23 non-null     object
#  2   SUMATERA BARAT        23 non-null     object
#  3   RIAU                  23 non-null     object
#  4   JAMBI                 23 non-null     object
#  5   SUMATERA SELATAN      23 non-null     object
#  6   BENGKULU              23 non-null     object
#  7   LAMPUNG               23 non-null     object
#  8   KEP. BANGKA BELITUNG  23 non-null     object
#  9   KEP. RIAU             23 non-null     object
#  10  DKI JAKARTA           23 non-null     object
#  11  JAWA BARAT            23 non-null     object
#  12  JAWA TENGAH           23 non-null     object
#  13  DI YOGYAKARTA         23 non-null     object
#  14  JAWA TIMUR            23 non-null     object
#  15  BANTEN                23 non-null     object
#  16  BALI                  23 non-null     object
#  17  NUSA TENGGARA BARAT   23 non-null     object
#  18  NUSA TENGGARA TIMUR   23 non-null     object
#  19  KALIMANTAN BARAT      23 non-null     object
#  20  KALIMANTAN TENGAH     23 non-null     object
#  21  KALIMANTAN SELATAN    23 non-null     object
#  22  KALIMANTAN TIMUR      23 non-null     object
#  23  KALIMANTAN UTARA      23 non-null     object
#  24  SULAWESI UTARA        23 non-null     object
#  25  SULAWESI TENGAH       23 non-null     object
#  26  SULAWESI SELATAN      23 non-null     object
#  27  SULAWESI TENGGARA     23 non-null     object
#  28  GORONTALO             23 non-null     object
#  29  SULAWESI BARAT        23 non-null     object
#  30  MALUKU                23 non-null     object
#  31  MALUKU UTARA          23 non-null     object
#  32  PAPUA BARAT           23 non-null     object
#  33  PAPUA                 23 non-null     object
# dtypes: float64(1), object(33)
# memory usage: 6.3+ KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.describe()
# Out:
# Provinsi          ACEH
# count     2.300000e+01
# mean      1.536389e+06
# std       2.522921e+05
# min       1.246614e+06
# 25%       1.375490e+06
# 50%       1.478712e+06
# 75%       1.569626e+06
# max       2.331046e+06

# %%
## finding all columns that have nan:

droping_list_all=[]
for j in range(0,7):
    if not df2.iloc[:, j].notnull().all():
        droping_list_all.append(j)        
        #print(df.iloc[:,j].unique())
droping_list_all
# Out:
# []

# %%
# filling nan with mean in any columns

for j in range(0,1):        
   df2.iloc[:,j]=df2.iloc[:,j].fillna(df2.iloc[:,j].mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
# another sanity check to make sure that there are not more any nan
df2.isnull().sum()
# Out:
# Provinsi
# ACEH                    0
# SUMATERA UTARA          0
# SUMATERA BARAT          0
# RIAU                    0
# JAMBI                   0
# SUMATERA SELATAN        0
# BENGKULU                0
# LAMPUNG                 0
# KEP. BANGKA BELITUNG    0
# KEP. RIAU               0
# DKI JAKARTA             0
# JAWA BARAT              0
# JAWA TENGAH             0
# DI YOGYAKARTA           0
# JAWA TIMUR              0
# BANTEN                  0
# BALI                    0
# NUSA TENGGARA BARAT     0
# NUSA TENGGARA TIMUR     0
# KALIMANTAN BARAT        0
# KALIMANTAN TENGAH       0
# KALIMANTAN SELATAN      0
# KALIMANTAN TIMUR        0
# KALIMANTAN UTARA        0
# SULAWESI UTARA          0
# SULAWESI TENGAH         0
# SULAWESI SELATAN        0
# SULAWESI TENGGARA       0
# GORONTALO               0
# SULAWESI BARAT          0
# MALUKU                  0
# MALUKU UTARA            0
# PAPUA BARAT             0
# PAPUA                   0
# dtype: int64

# %%
import matplotlib.pyplot as plt # this is used for the plot the graph 
df2.ACEH.plot(title='Aceh', color='red') 
plt.tight_layout()
plt.show()

# %%
training_set=df2.iloc[:,1:2].values
print(len(training_set))
# Out:
# 23

# %%
def normalise_windows(window_data):
    # A support function to normalize a dataset
    normalised_data = []
    for window in window_data:
        normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
        normalised_data.append(normalised_window)
    return normalised_data

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set = sc.fit_transform(training_set)

#training_set = normalise_windows(training_set)
print(training_set)
# Out:
# [[0.        ]
#  [0.14361525]
#  [0.19205238]
#  [0.19402899]
#  [0.26099406]
#  [0.35759761]
#  [0.47331933]
#  [0.52907888]
#  [0.33138424]
#  [0.20871377]
#  [0.43040108]
#  [0.44434208]
#  [0.46973711]
#  [0.07942294]
#  [0.30859066]
#  [0.3751226 ]
#  [0.5411906 ]
#  [0.58947684]
#  [0.61175563]
#  [0.70771126]
#  [0.71812685]
#  [0.63273414]
#  [1.        ]]

# %%
seq_len = 3
sequence_length = seq_len + 1
result = []
for index in range(len(training_set) - sequence_length):
    result.append(training_set[index: index + sequence_length])
result=np.array(result)
row = round(0.9 * result.shape[0])
print("training_set=",len(training_set))
print("row=",row)
# Out:
# training_set= 23
# row= 17

# %%
train = result[:int(row), :]
x_train = train[:, :-1]
y_train = train[:, -1]
x_test = result[int(row):, :-1]
y_test = result[int(row):, -1]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1)) 
print(x_train.shape)
print(x_test.shape)
# Out:
# (17, 3, 1)
# (2, 3, 1)

# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM, RNN
from keras.models import Sequential
from keras import optimizers

# The LSTM model I would like to test
# Note: replace LSTM with GRU or RNN if you want to try those

model = Sequential()
model.add(LSTM(10, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
#    model.add(LSTM(70))
#    model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

print ('model compiled')

print (model.summary())
# Out:
# model compiled
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 10)                480
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the model
history = model.fit(x_train, y_train, batch_size=5, epochs=100, validation_data = (x_test, y_test))

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0207 - val_loss: 0.0184
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0207 - val_loss: 0.0182
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0191 - val_loss: 0.0193
# Epoch 4/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0248 - val_loss: 0.0202
# Epoch 5/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0212 - val_loss: 0.0202
# Epoch 6/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0193 - val_loss: 0.0207
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0262 - val_loss: 0.0205
# Epoch 8/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0220 - val_loss: 0.0199
# Epoch 9/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0209 - val_loss: 0.0192
# Epoch 10/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0254 - val_loss: 0.0191
# Epoch 11/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0222 - val_loss: 0.0189
# Epoch 12/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0224 - val_loss: 0.0199
# Epoch 13/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0209 - val_loss: 0.0210
# Epoch 14/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0322 - val_loss: 0.0222
# Epoch 15/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0188 - val_loss: 0.0227
# Epoch 16/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0257 - val_loss: 0.0222
# Epoch 17/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0179 - val_loss: 0.0208
# Epoch 18/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0221 - val_loss: 0.0199
# Epoch 19/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0251 - val_loss: 0.0192
# Epoch 20/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.0179
# Epoch 21/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0255 - val_loss: 0.0179
# Epoch 22/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0187 - val_loss: 0.0183
# Epoch 23/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0189 - val_loss: 0.0181
# Epoch 24/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0279 - val_loss: 0.0173
# Epoch 25/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0221 - val_loss: 0.0175
# Epoch 26/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0257 - val_loss: 0.0181
# Epoch 27/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0231 - val_loss: 0.0193
# Epoch 28/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0192 - val_loss: 0.0214
# Epoch 29/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0249 - val_loss: 0.0221
# Epoch 30/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0216
# Epoch 31/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0189 - val_loss: 0.0211
# Epoch 32/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0290 - val_loss: 0.0212
# Epoch 33/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0253 - val_loss: 0.0211
# Epoch 34/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0199 - val_loss: 0.0206
# Epoch 35/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0245 - val_loss: 0.0195
# Epoch 36/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0197 - val_loss: 0.0186
# Epoch 37/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0176
# Epoch 38/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0226 - val_loss: 0.0172
# Epoch 39/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0214 - val_loss: 0.0173
# Epoch 40/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0215 - val_loss: 0.0182
# Epoch 41/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0256 - val_loss: 0.0193
# Epoch 42/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0219 - val_loss: 0.0196
# Epoch 43/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0221 - val_loss: 0.0191
# Epoch 44/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0177 - val_loss: 0.0189
# Epoch 45/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0297 - val_loss: 0.0185
# Epoch 46/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0247 - val_loss: 0.0192
# Epoch 47/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0198 - val_loss: 0.0186
# Epoch 48/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0223 - val_loss: 0.0181
# Epoch 49/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0240 - val_loss: 0.0194
# Epoch 50/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0266 - val_loss: 0.0199
# Epoch 51/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0223 - val_loss: 0.0202
# Epoch 52/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0176 - val_loss: 0.0196
# Epoch 53/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0281 - val_loss: 0.0183
# Epoch 54/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.0177
# Epoch 55/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0205 - val_loss: 0.0165
# Epoch 56/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0316 - val_loss: 0.0160
# Epoch 57/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0197 - val_loss: 0.0155
# Epoch 58/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0212 - val_loss: 0.0151
# Epoch 59/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0235 - val_loss: 0.0150
# Epoch 60/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0203 - val_loss: 0.0157
# Epoch 61/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0257 - val_loss: 0.0164
# Epoch 62/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0219 - val_loss: 0.0176
# Epoch 63/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0242 - val_loss: 0.0190
# Epoch 64/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0262 - val_loss: 0.0196
# Epoch 65/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0297 - val_loss: 0.0196
# Epoch 66/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0208 - val_loss: 0.0206
# Epoch 67/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0300 - val_loss: 0.0206
# Epoch 68/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0260 - val_loss: 0.0205
# Epoch 69/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0228 - val_loss: 0.0203
# Epoch 70/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0215 - val_loss: 0.0200
# Epoch 71/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0198 - val_loss: 0.0201
# Epoch 72/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0245 - val_loss: 0.0202
# Epoch 73/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0302 - val_loss: 0.0197
# Epoch 74/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0225 - val_loss: 0.0194
# Epoch 75/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0203 - val_loss: 0.0201
# Epoch 76/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0191 - val_loss: 0.0199
# Epoch 77/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0231 - val_loss: 0.0193
# Epoch 78/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0240 - val_loss: 0.0188
# Epoch 79/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0210 - val_loss: 0.0183
# Epoch 80/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0303 - val_loss: 0.0178
# Epoch 81/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0250 - val_loss: 0.0177
# Epoch 82/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0189 - val_loss: 0.0184
# Epoch 83/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0260 - val_loss: 0.0190
# Epoch 84/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0248 - val_loss: 0.0200
# Epoch 85/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0176 - val_loss: 0.0202
# Epoch 86/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0169 - val_loss: 0.0202
# Epoch 87/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0190 - val_loss: 0.0194
# Epoch 88/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0219 - val_loss: 0.0185
# Epoch 89/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0230 - val_loss: 0.0183
# Epoch 90/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0245 - val_loss: 0.0183
# Epoch 91/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0160 - val_loss: 0.0181
# Epoch 92/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0200 - val_loss: 0.0181
# Epoch 93/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0278 - val_loss: 0.0183
# Epoch 94/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0204 - val_loss: 0.0179
# Epoch 95/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0182 - val_loss: 0.0175
# Epoch 96/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0138 - val_loss: 0.0169
# Epoch 97/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0230 - val_loss: 0.0165
# Epoch 98/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0251 - val_loss: 0.0167
# Epoch 99/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0233 - val_loss: 0.0168
# Epoch 100/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0214 - val_loss: 0.0169

# %%
def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[np.newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

def plot_results(predicted_data, true_data): 
    fig = plt.figure(facecolor='white') 
    ax = fig.add_subplot(111) 
    ax.plot(true_data, label='True Data') 
    plt.plot(predicted_data, label='Prediction') 
    plt.legend() 
    plt.show() 

predictions= predict_sequence_full(model, x_test, seq_len)
plot_results(predictions,y_test)

# %%
# calculate RMSE
from sklearn.metrics import mean_squared_error,r2_score

mse = mean_squared_error(predictions, y_test)
rmse = np.sqrt(mean_squared_error(predictions, y_test))
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
#print('R2 Score: %.3f' % r2)
# Out:
# Test MSE: 0.021
# Test RMSE: 0.146
