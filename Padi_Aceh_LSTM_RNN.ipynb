# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3447c420-740d-47bd-b539-b8a13e273b10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3447c420-740d-47bd-b539-b8a13e273b10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Padi.csv to Padi.csv

# %%
import pandas as pd
df = pd.read_csv('Padi.csv')

# %%
df.head()
# Out:
#          Provinsi     1993     1994     1995     1996     1997     1998  \
# 0            ACEH  1299699  1329536  1368074  1419128  1382905  1486909
# 1  SUMATERA UTARA  2918152  3079960  3134533  3136760  3212208  3321049
# 2  SUMATERA BARAT  1806424  1747543  1829192  1971180  1787719  1807622
# 3            RIAU   436297   445361   458756   461905   416135   370124
# 4           JAMBI   607529   564722   593502   657650   572269   550277
#
#       1999     2000     2001  ...     2006     2007     2008     2009  \
# 0  1478712  1404580  1246614  ...  1350748  1533369  1402287  1556858
# 1  3451430  3514253  3291515  ...  3007636  3265834  3340794  3527899
# 2  1897678  1759059  1668955  ...  1889489  1938120  1965634  2105790
# 3   461630   431351   413391  ...    42938   490087   494260   531429
# 4   553641   536779   556564  ...   544597    58663   581704   644947
#
#       2010     2011     2012     2013     2014     2015
# 0  1582393  1772962  1788738  1956940  1820062  2331046
# 1  3582302  3607403  3715514  3727249  3631039  4044829
# 2  2211248  2279602  2368390  2430384  2519020  2550609
# 3   574864   535788   512152   434144   385475   393917
# 4   628828   646641   625164   664535   664720   541486
#
# [5 rows x 24 columns]

# %%
df_transpose = df.transpose()
df_transpose.head()
# Out:
#                0               1               2       3       4   \
# Provinsi     ACEH  SUMATERA UTARA  SUMATERA BARAT    RIAU   JAMBI
# 1993      1299699         2918152         1806424  436297  607529
# 1994      1329536         3079960         1747543  445361  564722
# 1995      1368074         3134533         1829192  458756  593502
# 1996      1419128         3136760         1971180  461905  657650
#
#                         5         6        7                     8   \
# Provinsi  SUMATERA SELATAN  BENGKULU  LAMPUNG  KEP. BANGKA BELITUNG
# 1993               1409559    356709  1646900                     -
# 1994               1347611    334232  1615751                     -
# 1995               1557944    377337  1943709                     -
# 1996               1666591    396977  1971740                     -
#
#                  9   ...              24               25                26  \
# Provinsi  KEP. RIAU  ...  SULAWESI UTARA  SULAWESI TENGAH  SULAWESI SELATAN
# 1993              -  ...          393314           462505           3303591
# 1994              -  ...          391186           449185           3467984
# 1995              -  ...          397113           539648           3727081
# 1996              -  ...          475018           583879           4052228
#
#                          27         28              29      30            31  \
# Provinsi  SULAWESI TENGGARA  GORONTALO  SULAWESI BARAT  MALUKU  MALUKU UTARA
# 1993                 220919          -               -   51330             -
# 1994                 246936          -               -   29904             -
# 1995                 287355          -               -   35151             -
# 1996                 305940          -               -   31240             -
#
#                    32     33
# Provinsi  PAPUA BARAT  PAPUA
# 1993                -  37090
# 1994                -  42864
# 1995                -  49115
# 1996                -  49903
#
# [5 rows x 34 columns]

# %%
header=df_transpose.iloc[0]
df2=df_transpose[1:]
df2.columns=header
df2.head()
# Out:
# Provinsi     ACEH SUMATERA UTARA SUMATERA BARAT    RIAU   JAMBI  \
# 1993      1299699        2918152        1806424  436297  607529
# 1994      1329536        3079960        1747543  445361  564722
# 1995      1368074        3134533        1829192  458756  593502
# 1996      1419128        3136760        1971180  461905  657650
# 1997      1382905        3212208        1787719  416135  572269
#
# Provinsi SUMATERA SELATAN BENGKULU  LAMPUNG KEP. BANGKA BELITUNG KEP. RIAU  \
# 1993              1409559   356709  1646900                    -         -
# 1994              1347611   334232  1615751                    -         -
# 1995              1557944   377337  1943709                    -         -
# 1996              1666591   396977  1971740                    -         -
# 1997              1577398   382123  1753656                    -         -
#
# Provinsi  ... SULAWESI UTARA SULAWESI TENGAH SULAWESI SELATAN  \
# 1993      ...         393314          462505          3303591
# 1994      ...         391186          449185          3467984
# 1995      ...         397113          539648          3727081
# 1996      ...         475018          583879          4052228
# 1997      ...         393593          523682          3769450
#
# Provinsi SULAWESI TENGGARA GORONTALO SULAWESI BARAT MALUKU MALUKU UTARA  \
# 1993                220919         -              -  51330            -
# 1994                246936         -              -  29904            -
# 1995                287355         -              -  35151            -
# 1996                305940         -              -  31240            -
# 1997                260334         -              -  17878            -
#
# Provinsi PAPUA BARAT  PAPUA
# 1993               -  37090
# 1994               -  42864
# 1995               -  49115
# 1996               -  49903
# 1997               -  38386
#
# [5 rows x 34 columns]

# %%
df2.describe()
# Out:
# Provinsi     ACEH SUMATERA UTARA SUMATERA BARAT    RIAU   JAMBI  \
# count          23             23             23      23      23
# unique         23             23             23      23      23
# top       1299699        2918152        1806424  436297  607529
# freq            1              1              1       1       1
#
# Provinsi SUMATERA SELATAN BENGKULU  LAMPUNG KEP. BANGKA BELITUNG KEP. RIAU  \
# count                  23       23       23                   23        23
# unique                 23       23       23                   16        12
# top               1409559   356709  1646900                    -         -
# freq                    1        1        1                    8        12
#
# Provinsi  ... SULAWESI UTARA SULAWESI TENGAH SULAWESI SELATAN  \
# count     ...             23              23               23
# unique    ...             23              23               23
# top       ...         393314          462505          3303591
# freq      ...              1               1                1
#
# Provinsi SULAWESI TENGGARA GORONTALO SULAWESI BARAT MALUKU MALUKU UTARA  \
# count                   23        23             23     23           23
# unique                  23        16             12     23           14
# top                 220919         -              -  51330            -
# freq                     1         8             12      1           10
#
# Provinsi PAPUA BARAT  PAPUA
# count             23     23
# unique            12     23
# top                -  37090
# freq              12      1
#
# [4 rows x 34 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 1993 to 2015
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ACEH                  23 non-null     object
#  1   SUMATERA UTARA        23 non-null     object
#  2   SUMATERA BARAT        23 non-null     object
#  3   RIAU                  23 non-null     object
#  4   JAMBI                 23 non-null     object
#  5   SUMATERA SELATAN      23 non-null     object
#  6   BENGKULU              23 non-null     object
#  7   LAMPUNG               23 non-null     object
#  8   KEP. BANGKA BELITUNG  23 non-null     object
#  9   KEP. RIAU             23 non-null     object
#  10  DKI JAKARTA           23 non-null     object
#  11  JAWA BARAT            23 non-null     object
#  12  JAWA TENGAH           23 non-null     object
#  13  DI YOGYAKARTA         23 non-null     object
#  14  JAWA TIMUR            23 non-null     object
#  15  BANTEN                23 non-null     object
#  16  BALI                  23 non-null     object
#  17  NUSA TENGGARA BARAT   23 non-null     object
#  18  NUSA TENGGARA TIMUR   23 non-null     object
#  19  KALIMANTAN BARAT      23 non-null     object
#  20  KALIMANTAN TENGAH     23 non-null     object
#  21  KALIMANTAN SELATAN    23 non-null     object
#  22  KALIMANTAN TIMUR      23 non-null     object
#  23  KALIMANTAN UTARA      23 non-null     object
#  24  SULAWESI UTARA        23 non-null     object
#  25  SULAWESI TENGAH       23 non-null     object
#  26  SULAWESI SELATAN      23 non-null     object
#  27  SULAWESI TENGGARA     23 non-null     object
#  28  GORONTALO             23 non-null     object
#  29  SULAWESI BARAT        23 non-null     object
#  30  MALUKU                23 non-null     object
#  31  MALUKU UTARA          23 non-null     object
#  32  PAPUA BARAT           23 non-null     object
#  33  PAPUA                 23 non-null     object
# dtypes: object(34)
# memory usage: 6.3+ KB

# %%
df2.dtypes
# Out:
# Provinsi
# ACEH                    object
# SUMATERA UTARA          object
# SUMATERA BARAT          object
# RIAU                    object
# JAMBI                   object
# SUMATERA SELATAN        object
# BENGKULU                object
# LAMPUNG                 object
# KEP. BANGKA BELITUNG    object
# KEP. RIAU               object
# DKI JAKARTA             object
# JAWA BARAT              object
# JAWA TENGAH             object
# DI YOGYAKARTA           object
# JAWA TIMUR              object
# BANTEN                  object
# BALI                    object
# NUSA TENGGARA BARAT     object
# NUSA TENGGARA TIMUR     object
# KALIMANTAN BARAT        object
# KALIMANTAN TENGAH       object
# KALIMANTAN SELATAN      object
# KALIMANTAN TIMUR        object
# KALIMANTAN UTARA        object
# SULAWESI UTARA          object
# SULAWESI TENGAH         object
# SULAWESI SELATAN        object
# SULAWESI TENGGARA       object
# GORONTALO               object
# SULAWESI BARAT          object
# MALUKU                  object
# MALUKU UTARA            object
# PAPUA BARAT             object
# PAPUA                   object
# dtype: object

# %%
df2.shape
# Out:
# (23, 34)

# %%
df2.columns
# Out:
# Index(['ACEH', 'SUMATERA UTARA', 'SUMATERA BARAT', 'RIAU', 'JAMBI',
#        'SUMATERA SELATAN', 'BENGKULU', 'LAMPUNG', 'KEP. BANGKA BELITUNG',
#        'KEP. RIAU', 'DKI JAKARTA', 'JAWA BARAT', 'JAWA TENGAH',
#        'DI YOGYAKARTA', 'JAWA TIMUR', 'BANTEN', 'BALI', 'NUSA TENGGARA BARAT',
#        'NUSA TENGGARA TIMUR', 'KALIMANTAN BARAT', 'KALIMANTAN TENGAH',
#        'KALIMANTAN SELATAN', 'KALIMANTAN TIMUR', 'KALIMANTAN UTARA',
#        'SULAWESI UTARA', 'SULAWESI TENGAH', 'SULAWESI SELATAN',
#        'SULAWESI TENGGARA', 'GORONTALO', 'SULAWESI BARAT', 'MALUKU',
#        'MALUKU UTARA', 'PAPUA BARAT', 'PAPUA'],
#       dtype='object', name='Provinsi')

# %%
df2['ACEH'] = df2['ACEH'].astype(float, errors = 'raise')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 1993 to 2015
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ACEH                  23 non-null     float64
#  1   SUMATERA UTARA        23 non-null     object
#  2   SUMATERA BARAT        23 non-null     object
#  3   RIAU                  23 non-null     object
#  4   JAMBI                 23 non-null     object
#  5   SUMATERA SELATAN      23 non-null     object
#  6   BENGKULU              23 non-null     object
#  7   LAMPUNG               23 non-null     object
#  8   KEP. BANGKA BELITUNG  23 non-null     object
#  9   KEP. RIAU             23 non-null     object
#  10  DKI JAKARTA           23 non-null     object
#  11  JAWA BARAT            23 non-null     object
#  12  JAWA TENGAH           23 non-null     object
#  13  DI YOGYAKARTA         23 non-null     object
#  14  JAWA TIMUR            23 non-null     object
#  15  BANTEN                23 non-null     object
#  16  BALI                  23 non-null     object
#  17  NUSA TENGGARA BARAT   23 non-null     object
#  18  NUSA TENGGARA TIMUR   23 non-null     object
#  19  KALIMANTAN BARAT      23 non-null     object
#  20  KALIMANTAN TENGAH     23 non-null     object
#  21  KALIMANTAN SELATAN    23 non-null     object
#  22  KALIMANTAN TIMUR      23 non-null     object
#  23  KALIMANTAN UTARA      23 non-null     object
#  24  SULAWESI UTARA        23 non-null     object
#  25  SULAWESI TENGAH       23 non-null     object
#  26  SULAWESI SELATAN      23 non-null     object
#  27  SULAWESI TENGGARA     23 non-null     object
#  28  GORONTALO             23 non-null     object
#  29  SULAWESI BARAT        23 non-null     object
#  30  MALUKU                23 non-null     object
#  31  MALUKU UTARA          23 non-null     object
#  32  PAPUA BARAT           23 non-null     object
#  33  PAPUA                 23 non-null     object
# dtypes: float64(1), object(33)
# memory usage: 6.3+ KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.describe()
# Out:
# Provinsi          ACEH
# count     2.300000e+01
# mean      1.536389e+06
# std       2.522921e+05
# min       1.246614e+06
# 25%       1.375490e+06
# 50%       1.478712e+06
# 75%       1.569626e+06
# max       2.331046e+06

# %%
## finding all columns that have nan:

droping_list_all=[]
for j in range(0,7):
    if not df2.iloc[:, j].notnull().all():
        droping_list_all.append(j)        
        #print(df.iloc[:,j].unique())
droping_list_all
# Out:
# []

# %%
# filling nan with mean in any columns

for j in range(0,1):        
   df2.iloc[:,j]=df2.iloc[:,j].fillna(df2.iloc[:,j].mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
# another sanity check to make sure that there are not more any nan
df2.isnull().sum()
# Out:
# Provinsi
# ACEH                    0
# SUMATERA UTARA          0
# SUMATERA BARAT          0
# RIAU                    0
# JAMBI                   0
# SUMATERA SELATAN        0
# BENGKULU                0
# LAMPUNG                 0
# KEP. BANGKA BELITUNG    0
# KEP. RIAU               0
# DKI JAKARTA             0
# JAWA BARAT              0
# JAWA TENGAH             0
# DI YOGYAKARTA           0
# JAWA TIMUR              0
# BANTEN                  0
# BALI                    0
# NUSA TENGGARA BARAT     0
# NUSA TENGGARA TIMUR     0
# KALIMANTAN BARAT        0
# KALIMANTAN TENGAH       0
# KALIMANTAN SELATAN      0
# KALIMANTAN TIMUR        0
# KALIMANTAN UTARA        0
# SULAWESI UTARA          0
# SULAWESI TENGAH         0
# SULAWESI SELATAN        0
# SULAWESI TENGGARA       0
# GORONTALO               0
# SULAWESI BARAT          0
# MALUKU                  0
# MALUKU UTARA            0
# PAPUA BARAT             0
# PAPUA                   0
# dtype: int64

# %%
import matplotlib.pyplot as plt # this is used for the plot the graph 
df2.ACEH.plot(title='Aceh', color='red') 
plt.tight_layout()
plt.show()

# %%
training_set=df2.iloc[:,1:2].values
print(len(training_set))
# Out:
# 23

# %%
def normalise_windows(window_data):
    # A support function to normalize a dataset
    normalised_data = []
    for window in window_data:
        normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
        normalised_data.append(normalised_window)
    return normalised_data

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set = sc.fit_transform(training_set)

#training_set = normalise_windows(training_set)
print(training_set)
# Out:
# [[0.        ]
#  [0.14361525]
#  [0.19205238]
#  [0.19402899]
#  [0.26099406]
#  [0.35759761]
#  [0.47331933]
#  [0.52907888]
#  [0.33138424]
#  [0.20871377]
#  [0.43040108]
#  [0.44434208]
#  [0.46973711]
#  [0.07942294]
#  [0.30859066]
#  [0.3751226 ]
#  [0.5411906 ]
#  [0.58947684]
#  [0.61175563]
#  [0.70771126]
#  [0.71812685]
#  [0.63273414]
#  [1.        ]]

# %%
import numpy as np
seq_len = 3
sequence_length = seq_len + 1
result = []
for index in range(len(training_set) - sequence_length):
    result.append(training_set[index: index + sequence_length])
result=np.array(result)
row = round(0.9 * result.shape[0])
print("training_set=",len(training_set))
print("row=",row)
# Out:
# training_set= 23
# row= 17

# %%
train = result[:int(row), :]
x_train = train[:, :-1]
y_train = train[:, -1]
x_test = result[int(row):, :-1]
y_test = result[int(row):, -1]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1)) 
print(x_train.shape)
print(x_test.shape)
# Out:
# (17, 3, 1)
# (2, 3, 1)

# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras import optimizers

# The LSTM model I would like to test
# Note: replace LSTM with GRU or RNN if you want to try those

model = Sequential()
model.add(LSTM(10, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
#    model.add(LSTM(70))
#    model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

print ('model compiled')

print (model.summary())
# Out:
# model compiled
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10)                480
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the model
history = model.fit(x_train, y_train, batch_size=5, epochs=100, validation_data = (x_test, y_test))

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 117ms/step - loss: 0.2292 - val_loss: 0.5357
# Epoch 2/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1962 - val_loss: 0.5014
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1966 - val_loss: 0.4686
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1822 - val_loss: 0.4379
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1645 - val_loss: 0.4082
# Epoch 6/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1543 - val_loss: 0.3793
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1423 - val_loss: 0.3515
# Epoch 8/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1390 - val_loss: 0.3255
# Epoch 9/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1219 - val_loss: 0.3010
# Epoch 10/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1101 - val_loss: 0.2776
# Epoch 11/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0989 - val_loss: 0.2547
# Epoch 12/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0919 - val_loss: 0.2330
# Epoch 13/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0828 - val_loss: 0.2128
# Epoch 14/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0751 - val_loss: 0.1939
# Epoch 15/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0613 - val_loss: 0.1752
# Epoch 16/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0558 - val_loss: 0.1576
# Epoch 17/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0520 - val_loss: 0.1414
# Epoch 18/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0474 - val_loss: 0.1270
# Epoch 19/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0391 - val_loss: 0.1140
# Epoch 20/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0446 - val_loss: 0.1010
# Epoch 21/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0417 - val_loss: 0.0899
# Epoch 22/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0413 - val_loss: 0.0806
# Epoch 23/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0307 - val_loss: 0.0720
# Epoch 24/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0267 - val_loss: 0.0646
# Epoch 25/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0317 - val_loss: 0.0573
# Epoch 26/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0266 - val_loss: 0.0523
# Epoch 27/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0186 - val_loss: 0.0488
# Epoch 28/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0289 - val_loss: 0.0456
# Epoch 29/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0310 - val_loss: 0.0426
# Epoch 30/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0270 - val_loss: 0.0410
# Epoch 31/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0209 - val_loss: 0.0397
# Epoch 32/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0252 - val_loss: 0.0386
# Epoch 33/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0246 - val_loss: 0.0371
# Epoch 34/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0299 - val_loss: 0.0361
# Epoch 35/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0265 - val_loss: 0.0356
# Epoch 36/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0289 - val_loss: 0.0355
# Epoch 37/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0376 - val_loss: 0.0343
# Epoch 38/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0291 - val_loss: 0.0339
# Epoch 39/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0284 - val_loss: 0.0340
# Epoch 40/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0306 - val_loss: 0.0346
# Epoch 41/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0209 - val_loss: 0.0340
# Epoch 42/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0247 - val_loss: 0.0331
# Epoch 43/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0275 - val_loss: 0.0325
# Epoch 44/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0223 - val_loss: 0.0329
# Epoch 45/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0279 - val_loss: 0.0324
# Epoch 46/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0264 - val_loss: 0.0318
# Epoch 47/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0329 - val_loss: 0.0320
# Epoch 48/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0223 - val_loss: 0.0325
# Epoch 49/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0250 - val_loss: 0.0328
# Epoch 50/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0299 - val_loss: 0.0335
# Epoch 51/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0221 - val_loss: 0.0342
# Epoch 52/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0255 - val_loss: 0.0345
# Epoch 53/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0308 - val_loss: 0.0352
# Epoch 54/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0231 - val_loss: 0.0376
# Epoch 55/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0148 - val_loss: 0.0386
# Epoch 56/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0279 - val_loss: 0.0382
# Epoch 57/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0336 - val_loss: 0.0367
# Epoch 58/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0272 - val_loss: 0.0352
# Epoch 59/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0315 - val_loss: 0.0347
# Epoch 60/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0163 - val_loss: 0.0335
# Epoch 61/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0384 - val_loss: 0.0320
# Epoch 62/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0274 - val_loss: 0.0292
# Epoch 63/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0254 - val_loss: 0.0275
# Epoch 64/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0246 - val_loss: 0.0265
# Epoch 65/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0224 - val_loss: 0.0258
# Epoch 66/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0397 - val_loss: 0.0251
# Epoch 67/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0273 - val_loss: 0.0257
# Epoch 68/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0168 - val_loss: 0.0263
# Epoch 69/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0269 - val_loss: 0.0268
# Epoch 70/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0301 - val_loss: 0.0283
# Epoch 71/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0340 - val_loss: 0.0312
# Epoch 72/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0208 - val_loss: 0.0330
# Epoch 73/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0253 - val_loss: 0.0353
# Epoch 74/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.0369
# Epoch 75/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0223 - val_loss: 0.0369
# Epoch 76/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0228 - val_loss: 0.0367
# Epoch 77/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0303 - val_loss: 0.0356
# Epoch 78/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0193 - val_loss: 0.0323
# Epoch 79/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0260 - val_loss: 0.0300
# Epoch 80/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0353 - val_loss: 0.0286
# Epoch 81/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0302 - val_loss: 0.0293
# Epoch 82/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0252 - val_loss: 0.0321
# Epoch 83/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0193 - val_loss: 0.0340
# Epoch 84/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0180 - val_loss: 0.0353
# Epoch 85/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0299 - val_loss: 0.0356
# Epoch 86/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0298 - val_loss: 0.0355
# Epoch 87/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0222 - val_loss: 0.0351
# Epoch 88/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0306 - val_loss: 0.0349
# Epoch 89/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0271 - val_loss: 0.0338
# Epoch 90/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0295 - val_loss: 0.0320
# Epoch 91/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0223 - val_loss: 0.0317
# Epoch 92/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0290 - val_loss: 0.0305
# Epoch 93/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0270 - val_loss: 0.0307
# Epoch 94/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0209 - val_loss: 0.0316
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0261 - val_loss: 0.0335
# Epoch 96/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0276 - val_loss: 0.0346
# Epoch 97/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0258 - val_loss: 0.0347
# Epoch 98/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0279 - val_loss: 0.0338
# Epoch 99/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0224 - val_loss: 0.0346
# Epoch 100/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0249 - val_loss: 0.0347

# %%
def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[np.newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

def plot_results(predicted_data, true_data): 
    fig = plt.figure(facecolor='white') 
    ax = fig.add_subplot(111) 
    ax.plot(true_data, label='True Data') 
    plt.plot(predicted_data, label='Prediction') 
    plt.legend() 
    plt.show() 

predictions= predict_sequence_full(model, x_test, seq_len)
plot_results(predictions,y_test)

# %%
# calculate RMSE
from sklearn.metrics import mean_squared_error,r2_score

mse = mean_squared_error(predictions, y_test)
rmse = np.sqrt(mean_squared_error(predictions, y_test))
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test MSE: 0.038
# Test RMSE: 0.195

# %%
from keras.layers.recurrent import SimpleRNN
# The RNN model I would like to test

model = Sequential()
model.add(SimpleRNN(10, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
#    model.add(LSTM(70))
#    model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

print ('model compiled')

print (model.summary())
# Out:
# model compiled
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 10)                120
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the model
history = model.fit(x_train, y_train, batch_size=5, epochs=100, validation_data = (x_test, y_test))

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 69ms/step - loss: 0.5128 - val_loss: 1.1318
# Epoch 2/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4243 - val_loss: 0.9481
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3720 - val_loss: 0.7917
# Epoch 4/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3107 - val_loss: 0.6507
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2304 - val_loss: 0.5285
# Epoch 6/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1547 - val_loss: 0.4263
# Epoch 7/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1670 - val_loss: 0.3406
# Epoch 8/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0809 - val_loss: 0.2737
# Epoch 9/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1186 - val_loss: 0.2179
# Epoch 10/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1205 - val_loss: 0.1725
# Epoch 11/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1005 - val_loss: 0.1322
# Epoch 12/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1345 - val_loss: 0.1038
# Epoch 13/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0824 - val_loss: 0.0854
# Epoch 14/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0706 - val_loss: 0.0678
# Epoch 15/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0591 - val_loss: 0.0578
# Epoch 16/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0978 - val_loss: 0.0522
# Epoch 17/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0391 - val_loss: 0.0505
# Epoch 18/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0454 - val_loss: 0.0484
# Epoch 19/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0691 - val_loss: 0.0473
# Epoch 20/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0472 - val_loss: 0.0488
# Epoch 21/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0491 - val_loss: 0.0523
# Epoch 22/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0586 - val_loss: 0.0552
# Epoch 23/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0506 - val_loss: 0.0540
# Epoch 24/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0627 - val_loss: 0.0522
# Epoch 25/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0776 - val_loss: 0.0480
# Epoch 26/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0750 - val_loss: 0.0439
# Epoch 27/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0544 - val_loss: 0.0422
# Epoch 28/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0431 - val_loss: 0.0435
# Epoch 29/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0311 - val_loss: 0.0427
# Epoch 30/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0546 - val_loss: 0.0454
# Epoch 31/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0550 - val_loss: 0.0494
# Epoch 32/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0533 - val_loss: 0.0509
# Epoch 33/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0540 - val_loss: 0.0490
# Epoch 34/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0490 - val_loss: 0.0488
# Epoch 35/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0776 - val_loss: 0.0492
# Epoch 36/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0320 - val_loss: 0.0491
# Epoch 37/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0387 - val_loss: 0.0494
# Epoch 38/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0381 - val_loss: 0.0497
# Epoch 39/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0433 - val_loss: 0.0498
# Epoch 40/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0431 - val_loss: 0.0485
# Epoch 41/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0287 - val_loss: 0.0466
# Epoch 42/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0348 - val_loss: 0.0484
# Epoch 43/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0346 - val_loss: 0.0507
# Epoch 44/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0396 - val_loss: 0.0517
# Epoch 45/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0543 - val_loss: 0.0541
# Epoch 46/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0341 - val_loss: 0.0547
# Epoch 47/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0275 - val_loss: 0.0562
# Epoch 48/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0487 - val_loss: 0.0599
# Epoch 49/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0272 - val_loss: 0.0602
# Epoch 50/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0531 - val_loss: 0.0617
# Epoch 51/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0327 - val_loss: 0.0607
# Epoch 52/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0429 - val_loss: 0.0573
# Epoch 53/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0494 - val_loss: 0.0534
# Epoch 54/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0372 - val_loss: 0.0484
# Epoch 55/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0270 - val_loss: 0.0425
# Epoch 56/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0498 - val_loss: 0.0381
# Epoch 57/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0344 - val_loss: 0.0364
# Epoch 58/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0496 - val_loss: 0.0383
# Epoch 59/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0306 - val_loss: 0.0408
# Epoch 60/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0387 - val_loss: 0.0432
# Epoch 61/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0273 - val_loss: 0.0439
# Epoch 62/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0432 - val_loss: 0.0405
# Epoch 63/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0393 - val_loss: 0.0379
# Epoch 64/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0311 - val_loss: 0.0360
# Epoch 65/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0327 - val_loss: 0.0356
# Epoch 66/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0246 - val_loss: 0.0366
# Epoch 67/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0474 - val_loss: 0.0360
# Epoch 68/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0346 - val_loss: 0.0328
# Epoch 69/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0362 - val_loss: 0.0303
# Epoch 70/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0436 - val_loss: 0.0286
# Epoch 71/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0387 - val_loss: 0.0287
# Epoch 72/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0291 - val_loss: 0.0318
# Epoch 73/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0410 - val_loss: 0.0346
# Epoch 74/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0525 - val_loss: 0.0385
# Epoch 75/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0225 - val_loss: 0.0410
# Epoch 76/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0264 - val_loss: 0.0442
# Epoch 77/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0280 - val_loss: 0.0452
# Epoch 78/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0593 - val_loss: 0.0457
# Epoch 79/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0390 - val_loss: 0.0456
# Epoch 80/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0171 - val_loss: 0.0459
# Epoch 81/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0189 - val_loss: 0.0473
# Epoch 82/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0399 - val_loss: 0.0471
# Epoch 83/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0196 - val_loss: 0.0475
# Epoch 84/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0265 - val_loss: 0.0460
# Epoch 85/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0367 - val_loss: 0.0431
# Epoch 86/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0382 - val_loss: 0.0394
# Epoch 87/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0336 - val_loss: 0.0386
# Epoch 88/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0444 - val_loss: 0.0384
# Epoch 89/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0278 - val_loss: 0.0374
# Epoch 90/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0455 - val_loss: 0.0375
# Epoch 91/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0405 - val_loss: 0.0352
# Epoch 92/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0269 - val_loss: 0.0325
# Epoch 93/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0372 - val_loss: 0.0303
# Epoch 94/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0291 - val_loss: 0.0308
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0362 - val_loss: 0.0336
# Epoch 96/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0351 - val_loss: 0.0366
# Epoch 97/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0321 - val_loss: 0.0419
# Epoch 98/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0254 - val_loss: 0.0429
# Epoch 99/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0337 - val_loss: 0.0427
# Epoch 100/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0226 - val_loss: 0.0425

# %%
predictions= predict_sequence_full(model, x_test, seq_len)
plot_results(predictions,y_test)

# %%
# calculate RMSE
from sklearn.metrics import mean_squared_error,r2_score

mse = mean_squared_error(predictions, y_test)
rmse = np.sqrt(mean_squared_error(predictions, y_test))
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test MSE: 0.049
# Test RMSE: 0.222
