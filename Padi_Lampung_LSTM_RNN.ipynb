# %% [markdown]
# #Data Set Padi Provinsi Lampung

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ce9b6100-d4c2-49f7-a63e-8dcd9883d937" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce9b6100-d4c2-49f7-a63e-8dcd9883d937">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Padi.csv to Padi.csv

# %%
import pandas as pd
df = pd.read_csv('Padi.csv')

# %%
df.head()
# Out:
#          Provinsi     1993     1994     1995     1996     1997     1998  \
# 0            ACEH  1299699  1329536  1368074  1419128  1382905  1486909
# 1  SUMATERA UTARA  2918152  3079960  3134533  3136760  3212208  3321049
# 2  SUMATERA BARAT  1806424  1747543  1829192  1971180  1787719  1807622
# 3            RIAU   436297   445361   458756   461905   416135   370124
# 4           JAMBI   607529   564722   593502   657650   572269   550277
#
#       1999     2000     2001  ...     2006     2007     2008     2009  \
# 0  1478712  1404580  1246614  ...  1350748  1533369  1402287  1556858
# 1  3451430  3514253  3291515  ...  3007636  3265834  3340794  3527899
# 2  1897678  1759059  1668955  ...  1889489  1938120  1965634  2105790
# 3   461630   431351   413391  ...    42938   490087   494260   531429
# 4   553641   536779   556564  ...   544597    58663   581704   644947
#
#       2010     2011     2012     2013     2014     2015
# 0  1582393  1772962  1788738  1956940  1820062  2331046
# 1  3582302  3607403  3715514  3727249  3631039  4044829
# 2  2211248  2279602  2368390  2430384  2519020  2550609
# 3   574864   535788   512152   434144   385475   393917
# 4   628828   646641   625164   664535   664720   541486
#
# [5 rows x 24 columns]

# %%
df_transpose = df.transpose()
df_transpose.head()
# Out:
#                0               1               2       3       4   \
# Provinsi     ACEH  SUMATERA UTARA  SUMATERA BARAT    RIAU   JAMBI
# 1993      1299699         2918152         1806424  436297  607529
# 1994      1329536         3079960         1747543  445361  564722
# 1995      1368074         3134533         1829192  458756  593502
# 1996      1419128         3136760         1971180  461905  657650
#
#                         5         6        7                     8   \
# Provinsi  SUMATERA SELATAN  BENGKULU  LAMPUNG  KEP. BANGKA BELITUNG
# 1993               1409559    356709  1646900                     -
# 1994               1347611    334232  1615751                     -
# 1995               1557944    377337  1943709                     -
# 1996               1666591    396977  1971740                     -
#
#                  9   ...              24               25                26  \
# Provinsi  KEP. RIAU  ...  SULAWESI UTARA  SULAWESI TENGAH  SULAWESI SELATAN
# 1993              -  ...          393314           462505           3303591
# 1994              -  ...          391186           449185           3467984
# 1995              -  ...          397113           539648           3727081
# 1996              -  ...          475018           583879           4052228
#
#                          27         28              29      30            31  \
# Provinsi  SULAWESI TENGGARA  GORONTALO  SULAWESI BARAT  MALUKU  MALUKU UTARA
# 1993                 220919          -               -   51330             -
# 1994                 246936          -               -   29904             -
# 1995                 287355          -               -   35151             -
# 1996                 305940          -               -   31240             -
#
#                    32     33
# Provinsi  PAPUA BARAT  PAPUA
# 1993                -  37090
# 1994                -  42864
# 1995                -  49115
# 1996                -  49903
#
# [5 rows x 34 columns]

# %%
header=df_transpose.iloc[0]
df2=df_transpose[1:]
df2.columns=header
df2.head()
# Out:
# Provinsi     ACEH SUMATERA UTARA SUMATERA BARAT    RIAU   JAMBI  \
# 1993      1299699        2918152        1806424  436297  607529
# 1994      1329536        3079960        1747543  445361  564722
# 1995      1368074        3134533        1829192  458756  593502
# 1996      1419128        3136760        1971180  461905  657650
# 1997      1382905        3212208        1787719  416135  572269
#
# Provinsi SUMATERA SELATAN BENGKULU  LAMPUNG KEP. BANGKA BELITUNG KEP. RIAU  \
# 1993              1409559   356709  1646900                    -         -
# 1994              1347611   334232  1615751                    -         -
# 1995              1557944   377337  1943709                    -         -
# 1996              1666591   396977  1971740                    -         -
# 1997              1577398   382123  1753656                    -         -
#
# Provinsi  ... SULAWESI UTARA SULAWESI TENGAH SULAWESI SELATAN  \
# 1993      ...         393314          462505          3303591
# 1994      ...         391186          449185          3467984
# 1995      ...         397113          539648          3727081
# 1996      ...         475018          583879          4052228
# 1997      ...         393593          523682          3769450
#
# Provinsi SULAWESI TENGGARA GORONTALO SULAWESI BARAT MALUKU MALUKU UTARA  \
# 1993                220919         -              -  51330            -
# 1994                246936         -              -  29904            -
# 1995                287355         -              -  35151            -
# 1996                305940         -              -  31240            -
# 1997                260334         -              -  17878            -
#
# Provinsi PAPUA BARAT  PAPUA
# 1993               -  37090
# 1994               -  42864
# 1995               -  49115
# 1996               -  49903
# 1997               -  38386
#
# [5 rows x 34 columns]

# %%
df2.describe()
# Out:
# Provinsi     ACEH SUMATERA UTARA SUMATERA BARAT    RIAU   JAMBI  \
# count          23             23             23      23      23
# unique         23             23             23      23      23
# top       1299699        2918152        1806424  436297  607529
# freq            1              1              1       1       1
#
# Provinsi SUMATERA SELATAN BENGKULU  LAMPUNG KEP. BANGKA BELITUNG KEP. RIAU  \
# count                  23       23       23                   23        23
# unique                 23       23       23                   16        12
# top               1409559   356709  1646900                    -         -
# freq                    1        1        1                    8        12
#
# Provinsi  ... SULAWESI UTARA SULAWESI TENGAH SULAWESI SELATAN  \
# count     ...             23              23               23
# unique    ...             23              23               23
# top       ...         393314          462505          3303591
# freq      ...              1               1                1
#
# Provinsi SULAWESI TENGGARA GORONTALO SULAWESI BARAT MALUKU MALUKU UTARA  \
# count                   23        23             23     23           23
# unique                  23        16             12     23           14
# top                 220919         -              -  51330            -
# freq                     1         8             12      1           10
#
# Provinsi PAPUA BARAT  PAPUA
# count             23     23
# unique            12     23
# top                -  37090
# freq              12      1
#
# [4 rows x 34 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 1993 to 2015
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ACEH                  23 non-null     object
#  1   SUMATERA UTARA        23 non-null     object
#  2   SUMATERA BARAT        23 non-null     object
#  3   RIAU                  23 non-null     object
#  4   JAMBI                 23 non-null     object
#  5   SUMATERA SELATAN      23 non-null     object
#  6   BENGKULU              23 non-null     object
#  7   LAMPUNG               23 non-null     object
#  8   KEP. BANGKA BELITUNG  23 non-null     object
#  9   KEP. RIAU             23 non-null     object
#  10  DKI JAKARTA           23 non-null     object
#  11  JAWA BARAT            23 non-null     object
#  12  JAWA TENGAH           23 non-null     object
#  13  DI YOGYAKARTA         23 non-null     object
#  14  JAWA TIMUR            23 non-null     object
#  15  BANTEN                23 non-null     object
#  16  BALI                  23 non-null     object
#  17  NUSA TENGGARA BARAT   23 non-null     object
#  18  NUSA TENGGARA TIMUR   23 non-null     object
#  19  KALIMANTAN BARAT      23 non-null     object
#  20  KALIMANTAN TENGAH     23 non-null     object
#  21  KALIMANTAN SELATAN    23 non-null     object
#  22  KALIMANTAN TIMUR      23 non-null     object
#  23  KALIMANTAN UTARA      23 non-null     object
#  24  SULAWESI UTARA        23 non-null     object
#  25  SULAWESI TENGAH       23 non-null     object
#  26  SULAWESI SELATAN      23 non-null     object
#  27  SULAWESI TENGGARA     23 non-null     object
#  28  GORONTALO             23 non-null     object
#  29  SULAWESI BARAT        23 non-null     object
#  30  MALUKU                23 non-null     object
#  31  MALUKU UTARA          23 non-null     object
#  32  PAPUA BARAT           23 non-null     object
#  33  PAPUA                 23 non-null     object
# dtypes: object(34)
# memory usage: 6.3+ KB

# %%
df2.dtypes
# Out:
# Provinsi
# ACEH                    object
# SUMATERA UTARA          object
# SUMATERA BARAT          object
# RIAU                    object
# JAMBI                   object
# SUMATERA SELATAN        object
# BENGKULU                object
# LAMPUNG                 object
# KEP. BANGKA BELITUNG    object
# KEP. RIAU               object
# DKI JAKARTA             object
# JAWA BARAT              object
# JAWA TENGAH             object
# DI YOGYAKARTA           object
# JAWA TIMUR              object
# BANTEN                  object
# BALI                    object
# NUSA TENGGARA BARAT     object
# NUSA TENGGARA TIMUR     object
# KALIMANTAN BARAT        object
# KALIMANTAN TENGAH       object
# KALIMANTAN SELATAN      object
# KALIMANTAN TIMUR        object
# KALIMANTAN UTARA        object
# SULAWESI UTARA          object
# SULAWESI TENGAH         object
# SULAWESI SELATAN        object
# SULAWESI TENGGARA       object
# GORONTALO               object
# SULAWESI BARAT          object
# MALUKU                  object
# MALUKU UTARA            object
# PAPUA BARAT             object
# PAPUA                   object
# dtype: object

# %%
df2.shape
# Out:
# (23, 34)

# %%
df2.columns
# Out:
# Index(['ACEH', 'SUMATERA UTARA', 'SUMATERA BARAT', 'RIAU', 'JAMBI',
#        'SUMATERA SELATAN', 'BENGKULU', 'LAMPUNG', 'KEP. BANGKA BELITUNG',
#        'KEP. RIAU', 'DKI JAKARTA', 'JAWA BARAT', 'JAWA TENGAH',
#        'DI YOGYAKARTA', 'JAWA TIMUR', 'BANTEN', 'BALI', 'NUSA TENGGARA BARAT',
#        'NUSA TENGGARA TIMUR', 'KALIMANTAN BARAT', 'KALIMANTAN TENGAH',
#        'KALIMANTAN SELATAN', 'KALIMANTAN TIMUR', 'KALIMANTAN UTARA',
#        'SULAWESI UTARA', 'SULAWESI TENGAH', 'SULAWESI SELATAN',
#        'SULAWESI TENGGARA', 'GORONTALO', 'SULAWESI BARAT', 'MALUKU',
#        'MALUKU UTARA', 'PAPUA BARAT', 'PAPUA'],
#       dtype='object', name='Provinsi')

# %%
df2['ACEH'] = df2['ACEH'].astype(float, errors = 'raise')
df2['LAMPUNG'] = df2['LAMPUNG'].astype(float, errors = 'raise')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23 entries, 1993 to 2015
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ACEH                  23 non-null     float64
#  1   SUMATERA UTARA        23 non-null     object
#  2   SUMATERA BARAT        23 non-null     object
#  3   RIAU                  23 non-null     object
#  4   JAMBI                 23 non-null     object
#  5   SUMATERA SELATAN      23 non-null     object
#  6   BENGKULU              23 non-null     object
#  7   LAMPUNG               23 non-null     float64
#  8   KEP. BANGKA BELITUNG  23 non-null     object
#  9   KEP. RIAU             23 non-null     object
#  10  DKI JAKARTA           23 non-null     object
#  11  JAWA BARAT            23 non-null     object
#  12  JAWA TENGAH           23 non-null     object
#  13  DI YOGYAKARTA         23 non-null     object
#  14  JAWA TIMUR            23 non-null     object
#  15  BANTEN                23 non-null     object
#  16  BALI                  23 non-null     object
#  17  NUSA TENGGARA BARAT   23 non-null     object
#  18  NUSA TENGGARA TIMUR   23 non-null     object
#  19  KALIMANTAN BARAT      23 non-null     object
#  20  KALIMANTAN TENGAH     23 non-null     object
#  21  KALIMANTAN SELATAN    23 non-null     object
#  22  KALIMANTAN TIMUR      23 non-null     object
#  23  KALIMANTAN UTARA      23 non-null     object
#  24  SULAWESI UTARA        23 non-null     object
#  25  SULAWESI TENGAH       23 non-null     object
#  26  SULAWESI SELATAN      23 non-null     object
#  27  SULAWESI TENGGARA     23 non-null     object
#  28  GORONTALO             23 non-null     object
#  29  SULAWESI BARAT        23 non-null     object
#  30  MALUKU                23 non-null     object
#  31  MALUKU UTARA          23 non-null     object
#  32  PAPUA BARAT           23 non-null     object
#  33  PAPUA                 23 non-null     object
# dtypes: float64(2), object(32)
# memory usage: 6.3+ KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2.describe()
# Out:
# Provinsi          ACEH       LAMPUNG
# count     2.300000e+01  2.300000e+01
# mean      1.536389e+06  2.315377e+06
# std       2.522921e+05  5.818448e+05
# min       1.246614e+06  1.615751e+06
# 25%       1.375490e+06  1.948758e+06
# 50%       1.478712e+06  2.091996e+06
# 75%       1.569626e+06  2.740760e+06
# max       2.331046e+06  3.641895e+06

# %%
## finding all columns that have nan:

droping_list_all=[]
for j in range(0,7):
    if not df2.iloc[:, j].notnull().all():
        droping_list_all.append(j)        
        #print(df.iloc[:,j].unique())
droping_list_all
# Out:
# []

# %%
# filling nan with mean in any columns

for j in range(0,1):        
   df2.iloc[:,j]=df2.iloc[:,j].fillna(df2.iloc[:,j].mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
# another sanity check to make sure that there are not more any nan
df2.isnull().sum()
# Out:
# Provinsi
# ACEH                    0
# SUMATERA UTARA          0
# SUMATERA BARAT          0
# RIAU                    0
# JAMBI                   0
# SUMATERA SELATAN        0
# BENGKULU                0
# LAMPUNG                 0
# KEP. BANGKA BELITUNG    0
# KEP. RIAU               0
# DKI JAKARTA             0
# JAWA BARAT              0
# JAWA TENGAH             0
# DI YOGYAKARTA           0
# JAWA TIMUR              0
# BANTEN                  0
# BALI                    0
# NUSA TENGGARA BARAT     0
# NUSA TENGGARA TIMUR     0
# KALIMANTAN BARAT        0
# KALIMANTAN TENGAH       0
# KALIMANTAN SELATAN      0
# KALIMANTAN TIMUR        0
# KALIMANTAN UTARA        0
# SULAWESI UTARA          0
# SULAWESI TENGAH         0
# SULAWESI SELATAN        0
# SULAWESI TENGGARA       0
# GORONTALO               0
# SULAWESI BARAT          0
# MALUKU                  0
# MALUKU UTARA            0
# PAPUA BARAT             0
# PAPUA                   0
# dtype: int64

# %%
import matplotlib.pyplot as plt # this is used for the plot the graph 
df2.LAMPUNG.plot(title='LAMPUNG', color='green') 
plt.tight_layout()
plt.show()

# %%
training_set=df2.iloc[:,7:8].values
print(len(training_set))
# Out:
# 23

# %%
def normalise_windows(window_data):
    # A support function to normalize a dataset
    normalised_data = []
    for window in window_data:
        normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
        normalised_data.append(normalised_window)
    return normalised_data

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set = sc.fit_transform(training_set)

#training_set = normalise_windows(training_set)
print(training_set)
# Out:
# [[0.01537354]
#  [0.        ]
#  [0.16186313]
#  [0.17569778]
#  [0.06806278]
#  [0.17765223]
#  [0.09163761]
#  [0.16319423]
#  [0.18605538]
#  [0.16551538]
#  [0.17300942]
#  [0.23504993]
#  [0.25091652]
#  [0.25376429]
#  [0.34185774]
#  [0.35798245]
#  [0.52222004]
#  [0.5882726 ]
#  [0.65397326]
#  [0.73326674]
#  [0.78535928]
#  [0.84116085]
#  [1.        ]]

# %%
import numpy as np
seq_len = 3
sequence_length = seq_len + 1
result = []
for index in range(len(training_set) - sequence_length):
    result.append(training_set[index: index + sequence_length])
result=np.array(result)
row = round(0.9 * result.shape[0])
print("training_set=",len(training_set))
print("row=",row)
# Out:
# training_set= 23
# row= 17

# %%
train = result[:int(row), :]
x_train = train[:, :-1]
y_train = train[:, -1]
x_test = result[int(row):, :-1]
y_test = result[int(row):, -1]
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1)) 
print(x_train.shape)
print(x_test.shape)
# Out:
# (17, 3, 1)
# (2, 3, 1)

# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras import optimizers

# The LSTM model I would like to test
# Note: replace LSTM with GRU or RNN if you want to try those

model = Sequential()
model.add(LSTM(10, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

print ('model compiled')

print (model.summary())
# Out:
# model compiled
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10)                480
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 491
# Trainable params: 491
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the model
history = model.fit(x_train, y_train, batch_size=5, epochs=100, validation_data = (x_test, y_test))

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 121ms/step - loss: 0.1381 - val_loss: 0.6870
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1310 - val_loss: 0.6411
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1028 - val_loss: 0.5978
# Epoch 4/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1121 - val_loss: 0.5586
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1097 - val_loss: 0.5209
# Epoch 6/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1024 - val_loss: 0.4867
# Epoch 7/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0729 - val_loss: 0.4516
# Epoch 8/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0693 - val_loss: 0.4186
# Epoch 9/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0489 - val_loss: 0.3902
# Epoch 10/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0605 - val_loss: 0.3623
# Epoch 11/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0472 - val_loss: 0.3370
# Epoch 12/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0462 - val_loss: 0.3120
# Epoch 13/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0392 - val_loss: 0.2892
# Epoch 14/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0439 - val_loss: 0.2694
# Epoch 15/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0327 - val_loss: 0.2536
# Epoch 16/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0442 - val_loss: 0.2382
# Epoch 17/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0293 - val_loss: 0.2239
# Epoch 18/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0395 - val_loss: 0.2105
# Epoch 19/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0336 - val_loss: 0.1984
# Epoch 20/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0267 - val_loss: 0.1880
# Epoch 21/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0269 - val_loss: 0.1782
# Epoch 22/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0323 - val_loss: 0.1679
# Epoch 23/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0210 - val_loss: 0.1588
# Epoch 24/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0357 - val_loss: 0.1494
# Epoch 25/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0244 - val_loss: 0.1430
# Epoch 26/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0277 - val_loss: 0.1370
# Epoch 27/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0189 - val_loss: 0.1331
# Epoch 28/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.1284
# Epoch 29/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0271 - val_loss: 0.1238
# Epoch 30/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0380 - val_loss: 0.1197
# Epoch 31/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0278 - val_loss: 0.1165
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0288 - val_loss: 0.1123
# Epoch 33/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0223 - val_loss: 0.1086
# Epoch 34/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0174 - val_loss: 0.1052
# Epoch 35/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0311 - val_loss: 0.1023
# Epoch 36/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0228 - val_loss: 0.0997
# Epoch 37/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0193 - val_loss: 0.0982
# Epoch 38/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0203 - val_loss: 0.0952
# Epoch 39/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0182 - val_loss: 0.0918
# Epoch 40/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0197 - val_loss: 0.0909
# Epoch 41/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0124 - val_loss: 0.0905
# Epoch 42/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0198 - val_loss: 0.0895
# Epoch 43/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0180 - val_loss: 0.0884
# Epoch 44/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0179 - val_loss: 0.0864
# Epoch 45/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0190 - val_loss: 0.0857
# Epoch 46/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0117 - val_loss: 0.0840
# Epoch 47/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0294 - val_loss: 0.0814
# Epoch 48/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0217 - val_loss: 0.0801
# Epoch 49/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0159 - val_loss: 0.0778
# Epoch 50/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0250 - val_loss: 0.0746
# Epoch 51/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0207 - val_loss: 0.0728
# Epoch 52/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0166 - val_loss: 0.0709
# Epoch 53/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0218 - val_loss: 0.0689
# Epoch 54/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0127 - val_loss: 0.0657
# Epoch 55/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0132 - val_loss: 0.0628
# Epoch 56/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0205 - val_loss: 0.0593
# Epoch 57/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0144 - val_loss: 0.0574
# Epoch 58/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0132 - val_loss: 0.0568
# Epoch 59/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0239 - val_loss: 0.0561
# Epoch 60/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 0.0560
# Epoch 61/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0156 - val_loss: 0.0554
# Epoch 62/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0109 - val_loss: 0.0548
# Epoch 63/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0208 - val_loss: 0.0537
# Epoch 64/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0136 - val_loss: 0.0529
# Epoch 65/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0123 - val_loss: 0.0526
# Epoch 66/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0299 - val_loss: 0.0521
# Epoch 67/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0160 - val_loss: 0.0507
# Epoch 68/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0125 - val_loss: 0.0497
# Epoch 69/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0205 - val_loss: 0.0466
# Epoch 70/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0126 - val_loss: 0.0450
# Epoch 71/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0116 - val_loss: 0.0427
# Epoch 72/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0117 - val_loss: 0.0418
# Epoch 73/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0155 - val_loss: 0.0400
# Epoch 74/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0372
# Epoch 75/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0106 - val_loss: 0.0345
# Epoch 76/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0131 - val_loss: 0.0317
# Epoch 77/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0118 - val_loss: 0.0292
# Epoch 78/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0126 - val_loss: 0.0271
# Epoch 79/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0161 - val_loss: 0.0253
# Epoch 80/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0352 - val_loss: 0.0232
# Epoch 81/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0144 - val_loss: 0.0224
# Epoch 82/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0106 - val_loss: 0.0215
# Epoch 83/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0123 - val_loss: 0.0203
# Epoch 84/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0229 - val_loss: 0.0195
# Epoch 85/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0193 - val_loss: 0.0187
# Epoch 86/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0118 - val_loss: 0.0173
# Epoch 87/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0087 - val_loss: 0.0158
# Epoch 88/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0071 - val_loss: 0.0151
# Epoch 89/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0090 - val_loss: 0.0145
# Epoch 90/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0201 - val_loss: 0.0137
# Epoch 91/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0061 - val_loss: 0.0136
# Epoch 92/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0118 - val_loss: 0.0136
# Epoch 93/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0178 - val_loss: 0.0134
# Epoch 94/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0124 - val_loss: 0.0122
# Epoch 95/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0167 - val_loss: 0.0114
# Epoch 96/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0068 - val_loss: 0.0104
# Epoch 97/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0097 - val_loss: 0.0101
# Epoch 98/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0067 - val_loss: 0.0094
# Epoch 99/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0092 - val_loss: 0.0084
# Epoch 100/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0080

# %%
def predict_sequence_full(model, data, window_size):
    #Shift the window by 1 new prediction each time, re-run predictions on new window
    curr_frame = data[0]
    predicted = []
    for i in range(len(data)):
        predicted.append(model.predict(curr_frame[np.newaxis,:,:])[0,0])
        curr_frame = curr_frame[1:]
        curr_frame = np.insert(curr_frame, [window_size-1], predicted[-1], axis=0)
    return predicted

def plot_results(predicted_data, true_data): 
    fig = plt.figure(facecolor='white') 
    ax = fig.add_subplot(111) 
    ax.plot(true_data, label='True Data') 
    plt.plot(predicted_data, label='Prediction') 
    plt.legend() 
    plt.show() 

predictions= predict_sequence_full(model, x_test, seq_len)
plot_results(predictions,y_test)

# %%
# calculate RMSE
from sklearn.metrics import mean_squared_error,r2_score

mse = mean_squared_error(predictions, y_test)
rmse = np.sqrt(mean_squared_error(predictions, y_test))
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test MSE: 0.010
# Test RMSE: 0.100

# %%
from keras.layers.recurrent import SimpleRNN
# The RNN model I would like to test

model = Sequential()
model.add(SimpleRNN(10, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
#    model.add(LSTM(70))
#    model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

print ('model compiled')

print (model.summary())
# Out:
# model compiled
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 10)                120
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Train the model
history = model.fit(x_train, y_train, batch_size=5, epochs=100, validation_data = (x_test, y_test))

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 74ms/step - loss: 0.0756 - val_loss: 0.1011
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0504 - val_loss: 0.0645
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0242 - val_loss: 0.0389
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0273
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0124 - val_loss: 0.0235
# Epoch 6/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0321 - val_loss: 0.0225
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0497 - val_loss: 0.0246
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0142 - val_loss: 0.0276
# Epoch 9/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0226 - val_loss: 0.0277
# Epoch 10/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0310 - val_loss: 0.0280
# Epoch 11/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0274
# Epoch 12/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0081 - val_loss: 0.0269
# Epoch 13/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0287 - val_loss: 0.0211
# Epoch 14/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0183 - val_loss: 0.0176
# Epoch 15/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0094 - val_loss: 0.0133
# Epoch 16/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0221 - val_loss: 0.0104
# Epoch 17/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0145 - val_loss: 0.0080
# Epoch 18/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0084 - val_loss: 0.0067
# Epoch 19/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 20/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0254 - val_loss: 0.0043
# Epoch 21/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0121 - val_loss: 0.0020
# Epoch 22/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0094 - val_loss: 0.0012
# Epoch 23/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0109 - val_loss: 0.0015
# Epoch 24/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0286 - val_loss: 0.0016
# Epoch 25/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0487 - val_loss: 0.0010
# Epoch 26/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0107 - val_loss: 0.0012
# Epoch 27/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0171 - val_loss: 0.0011
# Epoch 28/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0179 - val_loss: 2.8108e-04
# Epoch 29/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0268 - val_loss: 7.8837e-05
# Epoch 30/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0283 - val_loss: 8.1646e-05
# Epoch 31/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0088 - val_loss: 2.1958e-04
# Epoch 32/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0170 - val_loss: 6.2596e-04
# Epoch 33/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0081 - val_loss: 6.4761e-04
# Epoch 34/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0080 - val_loss: 9.8212e-04
# Epoch 35/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0088 - val_loss: 9.0973e-04
# Epoch 36/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0118 - val_loss: 4.9035e-04
# Epoch 37/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 1.6254e-04
# Epoch 38/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0100 - val_loss: 4.5650e-05
# Epoch 39/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0085 - val_loss: 1.2650e-04
# Epoch 40/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0119 - val_loss: 1.8054e-04
# Epoch 41/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 3.6486e-04
# Epoch 42/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0219 - val_loss: 3.0573e-04
# Epoch 43/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0065 - val_loss: 3.8653e-04
# Epoch 44/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0092 - val_loss: 8.2303e-04
# Epoch 45/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0057 - val_loss: 0.0015
# Epoch 46/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0071 - val_loss: 0.0010
# Epoch 47/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0137 - val_loss: 6.2457e-04
# Epoch 48/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0055 - val_loss: 4.3020e-05
# Epoch 49/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0190 - val_loss: 4.8855e-04
# Epoch 50/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0085 - val_loss: 0.0016
# Epoch 51/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0113 - val_loss: 0.0011
# Epoch 52/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0087 - val_loss: 5.7390e-04
# Epoch 53/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0094 - val_loss: 6.5711e-05
# Epoch 54/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0097 - val_loss: 4.4463e-04
# Epoch 55/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0095 - val_loss: 7.7015e-04
# Epoch 56/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0099 - val_loss: 2.2042e-04
# Epoch 57/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0064 - val_loss: 7.4538e-05
# Epoch 58/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0107 - val_loss: 1.3882e-04
# Epoch 59/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 2.5210e-04
# Epoch 60/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0117 - val_loss: 5.0223e-04
# Epoch 61/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0095 - val_loss: 5.0884e-04
# Epoch 62/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0133 - val_loss: 3.5551e-04
# Epoch 63/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0325 - val_loss: 6.9893e-05
# Epoch 64/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0084 - val_loss: 1.1605e-04
# Epoch 65/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0068 - val_loss: 8.4168e-05
# Epoch 66/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0060 - val_loss: 7.6437e-05
# Epoch 67/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0270 - val_loss: 2.2214e-04
# Epoch 68/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0205 - val_loss: 0.0011
# Epoch 69/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0118 - val_loss: 0.0019
# Epoch 70/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0141 - val_loss: 0.0031
# Epoch 71/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0132 - val_loss: 0.0033
# Epoch 72/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0174 - val_loss: 0.0037
# Epoch 73/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0084 - val_loss: 0.0027
# Epoch 74/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0088 - val_loss: 8.1242e-04
# Epoch 75/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0120 - val_loss: 2.7412e-04
# Epoch 76/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0115 - val_loss: 3.0949e-04
# Epoch 77/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 1.4255e-04
# Epoch 78/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0139 - val_loss: 9.3457e-05
# Epoch 79/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0074 - val_loss: 7.6641e-05
# Epoch 80/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0179 - val_loss: 6.2164e-05
# Epoch 81/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 7.0064e-05
# Epoch 82/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 8.7596e-05
# Epoch 83/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0136 - val_loss: 2.7308e-04
# Epoch 84/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 5.8671e-04
# Epoch 85/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0070 - val_loss: 7.5884e-04
# Epoch 86/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0098 - val_loss: 9.7141e-04
# Epoch 87/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0096 - val_loss: 0.0020
# Epoch 88/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0166 - val_loss: 0.0032
# Epoch 89/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0089 - val_loss: 0.0036
# Epoch 90/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 91/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0059 - val_loss: 4.4425e-04
# Epoch 92/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0084 - val_loss: 7.6525e-05
# Epoch 93/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0045 - val_loss: 1.3773e-04
# Epoch 94/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0141 - val_loss: 1.0591e-04
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0197 - val_loss: 1.7437e-04
# Epoch 96/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0062 - val_loss: 0.0015
# Epoch 97/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0057 - val_loss: 0.0035
# Epoch 98/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0075 - val_loss: 0.0044
# Epoch 99/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0076 - val_loss: 0.0036
# Epoch 100/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0022

# %%
predictions= predict_sequence_full(model, x_test, seq_len)
plot_results(predictions,y_test)

# %%
# calculate RMSE
from sklearn.metrics import mean_squared_error,r2_score

mse = mean_squared_error(predictions, y_test)
rmse = np.sqrt(mean_squared_error(predictions, y_test))
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test MSE: 0.002
# Test RMSE: 0.049
