# %% [markdown]
# ## **Import Library**

# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # **Import Data Set**

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5f6938fa-d144-493d-9445-da4bbaf067ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f6938fa-d144-493d-9445-da4bbaf067ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Padi.csv to Padi.csv

# %%
import pandas as pd
dt_padi = pd.read_csv('Padi.csv')
dt_padi.head()
# Out:
#          Provinsi     1993     1994     1995     1996     1997     1998  \
# 0            ACEH  1299699  1329536  1368074  1419128  1382905  1486909
# 1  SUMATERA UTARA  2918152  3079960  3134533  3136760  3212208  3321049
# 2  SUMATERA BARAT  1806424  1747543  1829192  1971180  1787719  1807622
# 3            RIAU   436297   445361   458756   461905   416135   370124
# 4           JAMBI   607529   564722   593502   657650   572269   550277
#
#       1999     2000     2001  ...     2006     2007     2008     2009  \
# 0  1478712  1404580  1246614  ...  1350748  1533369  1402287  1556858
# 1  3451430  3514253  3291515  ...  3007636  3265834  3340794  3527899
# 2  1897678  1759059  1668955  ...  1889489  1938120  1965634  2105790
# 3   461630   431351   413391  ...    42938   490087   494260   531429
# 4   553641   536779   556564  ...   544597    58663   581704   644947
#
#       2010     2011     2012     2013     2014     2015
# 0  1582393  1772962  1788738  1956940  1820062  2331046
# 1  3582302  3607403  3715514  3727249  3631039  4044829
# 2  2211248  2279602  2368390  2430384  2519020  2550609
# 3   574864   535788   512152   434144   385475   393917
# 4   628828   646641   625164   664535   664720   541486
#
# [5 rows x 24 columns]

# %% [markdown]
# ##Explore Dataset

# %%
provinsi = []

for values in dt_padi['Provinsi'].items():
  provinsi.append(values[1])
print(provinsi)
# Out:
# ['ACEH', 'SUMATERA UTARA', 'SUMATERA BARAT', 'RIAU', 'JAMBI', 'SUMATERA SELATAN', 'BENGKULU', 'LAMPUNG', 'KEP. BANGKA BELITUNG', 'KEP. RIAU', 'DKI JAKARTA', 'JAWA BARAT', 'JAWA TENGAH', 'DI YOGYAKARTA', 'JAWA TIMUR', 'BANTEN', 'BALI', 'NUSA TENGGARA BARAT', 'NUSA TENGGARA TIMUR', 'KALIMANTAN BARAT', 'KALIMANTAN TENGAH', 'KALIMANTAN SELATAN', 'KALIMANTAN TIMUR', 'KALIMANTAN UTARA', 'SULAWESI UTARA', 'SULAWESI TENGAH', 'SULAWESI SELATAN', 'SULAWESI TENGGARA', 'GORONTALO', 'SULAWESI BARAT', 'MALUKU', 'MALUKU UTARA', 'PAPUA BARAT', 'PAPUA']

# %%
rows = []

for prov in provinsi:
  nama_prov = prov
  df_prov = dt_padi.loc[dt_padi['Provinsi'] == nama_prov]
  index_prov = df_prov.index.values[0]

  for name, values in df_prov.items():
    value=values[index_prov]
    if(nama_prov != value):
      try:
        val = int(values[index_prov])
      except:
        val = 0
      rows.append([nama_prov, name, val])

print(rows)
# Out:
# [['ACEH', '1993', 1299699], ['ACEH', '1994', 1329536], ['ACEH', '1995', 1368074], ['ACEH', '1996', 1419128], ['ACEH', '1997', 1382905], ['ACEH', '1998', 1486909], ['ACEH', '1999', 1478712], ['ACEH', '2000', 1404580], ['ACEH', '2001', 1246614], ['ACEH', '2002', 1314165], ['ACEH', '2003', 1547499], ['ACEH', '2004', 1552078], ['ACEH', '2005', 1411650], ['ACEH', '2006', 1350748], ['ACEH', '2007', 1533369], ['ACEH', '2008', 1402287], ['ACEH', '2009', 1556858], ['ACEH', '2010', 1582393], ['ACEH', '2011', 1772962], ['ACEH', '2012', 1788738], ['ACEH', '2013', 1956940], ['ACEH', '2014', 1820062], ['ACEH', '2015', 2331046], ['SUMATERA UTARA', '1993', 2918152], ['SUMATERA UTARA', '1994', 3079960], ['SUMATERA UTARA', '1995', 3134533], ['SUMATERA UTARA', '1996', 3136760], ['SUMATERA UTARA', '1997', 3212208], ['SUMATERA UTARA', '1998', 3321049], ['SUMATERA UTARA', '1999', 3451430], ['SUMATERA UTARA', '2000', 3514253], ['SUMATERA UTARA', '2001', 3291515], ['SUMATERA UTARA', '2002', 3153305], ['SUMATERA UTARA', '2003', 3403075], ['SUMATERA UTARA', '2004', 3418782], ['SUMATERA UTARA', '2005', 3447394], ['SUMATERA UTARA', '2006', 3007636], ['SUMATERA UTARA', '2007', 3265834], ['SUMATERA UTARA', '2008', 3340794], ['SUMATERA UTARA', '2009', 3527899], ['SUMATERA UTARA', '2010', 3582302], ['SUMATERA UTARA', '2011', 3607403], ['SUMATERA UTARA', '2012', 3715514], ['SUMATERA UTARA', '2013', 3727249], ['SUMATERA UTARA', '2014', 3631039], ['SUMATERA UTARA', '2015', 4044829], ['SUMATERA BARAT', '1993', 1806424], ['SUMATERA BARAT', '1994', 1747543], ['SUMATERA BARAT', '1995', 1829192], ['SUMATERA BARAT', '1996', 1971180], ['SUMATERA BARAT', '1997', 1787719], ['SUMATERA BARAT', '1998', 1807622], ['SUMATERA BARAT', '1999', 1897678], ['SUMATERA BARAT', '2000', 1759059], ['SUMATERA BARAT', '2001', 1668955], ['SUMATERA BARAT', '2002', 1875834], ['SUMATERA BARAT', '2003', 1823739], ['SUMATERA BARAT', '2004', 1875188], ['SUMATERA BARAT', '2005', 1907390], ['SUMATERA BARAT', '2006', 1889489], ['SUMATERA BARAT', '2007', 1938120], ['SUMATERA BARAT', '2008', 1965634], ['SUMATERA BARAT', '2009', 2105790], ['SUMATERA BARAT', '2010', 2211248], ['SUMATERA BARAT', '2011', 2279602], ['SUMATERA BARAT', '2012', 2368390], ['SUMATERA BARAT', '2013', 2430384], ['SUMATERA BARAT', '2014', 2519020], ['SUMATERA BARAT', '2015', 2550609], ['RIAU', '1993', 436297], ['RIAU', '1994', 445361], ['RIAU', '1995', 458756], ['RIAU', '1996', 461905], ['RIAU', '1997', 416135], ['RIAU', '1998', 370124], ['RIAU', '1999', 461630], ['RIAU', '2000', 431351], ['RIAU', '2001', 413391], ['RIAU', '2002', 396644], ['RIAU', '2003', 414237], ['RIAU', '2004', 454186], ['RIAU', '2005', 424095], ['RIAU', '2006', 42938], ['RIAU', '2007', 490087], ['RIAU', '2008', 494260], ['RIAU', '2009', 531429], ['RIAU', '2010', 574864], ['RIAU', '2011', 535788], ['RIAU', '2012', 512152], ['RIAU', '2013', 434144], ['RIAU', '2014', 385475], ['RIAU', '2015', 393917], ['JAMBI', '1993', 607529], ['JAMBI', '1994', 564722], ['JAMBI', '1995', 593502], ['JAMBI', '1996', 657650], ['JAMBI', '1997', 572269], ['JAMBI', '1998', 550277], ['JAMBI', '1999', 553641], ['JAMBI', '2000', 536779], ['JAMBI', '2001', 556564], ['JAMBI', '2002', 561007], ['JAMBI', '2003', 578346], ['JAMBI', '2004', 579404], ['JAMBI', '2005', 579635], ['JAMBI', '2006', 544597], ['JAMBI', '2007', 58663], ['JAMBI', '2008', 581704], ['JAMBI', '2009', 644947], ['JAMBI', '2010', 628828], ['JAMBI', '2011', 646641], ['JAMBI', '2012', 625164], ['JAMBI', '2013', 664535], ['JAMBI', '2014', 664720], ['JAMBI', '2015', 541486], ['SUMATERA SELATAN', '1993', 1409559], ['SUMATERA SELATAN', '1994', 1347611], ['SUMATERA SELATAN', '1995', 1557944], ['SUMATERA SELATAN', '1996', 1666591], ['SUMATERA SELATAN', '1997', 1577398], ['SUMATERA SELATAN', '1998', 1931505], ['SUMATERA SELATAN', '1999', 1789961], ['SUMATERA SELATAN', '2000', 1863643], ['SUMATERA SELATAN', '2001', 1723433], ['SUMATERA SELATAN', '2002', 1899849], ['SUMATERA SELATAN', '2003', 1977345], ['SUMATERA SELATAN', '2004', 2 ...

# %%
df = pd.DataFrame(rows, columns=['Provinsi', 'Tahun', 'Produksi'])
df.set_index(['Provinsi','Tahun'], inplace=True)
df.head()
# Out:
#                 Produksi
# Provinsi Tahun
# ACEH     1993    1299699
#          1994    1329536
#          1995    1368074
#          1996    1419128
#          1997    1382905

# %%
df.to_csv('Padi.csv')

# %% [markdown]
# ##Create New Dataset

# %%
target_prov = 'ACEH'

# %%
rows = []

nama_prov = target_prov
df_prov = dt_padi.loc[dt_padi['Provinsi'] == nama_prov]
index_prov = df_prov.index.values[0]

for name, values in df_prov.items():
  value=values[index_prov]
  if(nama_prov != value):
    try:
      val = int(values[index_prov])
    except:
      val = 0
    rows.append([name, val])

print(rows)

df = pd.DataFrame(rows, columns=['Tahun', 'Produksi'])
df.set_index(['Tahun'], inplace=True)
df.head()

filename = target_prov + '_Padi.csv'
df.to_csv(filename)
# Out:
# [['1993', 1299699], ['1994', 1329536], ['1995', 1368074], ['1996', 1419128], ['1997', 1382905], ['1998', 1486909], ['1999', 1478712], ['2000', 1404580], ['2001', 1246614], ['2002', 1314165], ['2003', 1547499], ['2004', 1552078], ['2005', 1411650], ['2006', 1350748], ['2007', 1533369], ['2008', 1402287], ['2009', 1556858], ['2010', 1582393], ['2011', 1772962], ['2012', 1788738], ['2013', 1956940], ['2014', 1820062], ['2015', 2331046]]

# %% [markdown]
# # #Visualize

# %%
dataset_explore=pd.read_csv('/content/Padi.csv', index_col="Tahun")
dataset_explore.head()
dataset_explore.tail()
# Out:
#       Provinsi  Produksi
# Tahun
# 2011     PAPUA    115437
# 2012     PAPUA    138032
# 2013     PAPUA    169791
# 2014     PAPUA    196015
# 2015     PAPUA    181769

# %%
dataset_explore.columns
# Out:
# Index(['Provinsi', 'Produksi'], dtype='object')

# %%
for prov in provinsi:
  df_plot = dataset_explore.loc[dataset_explore['Provinsi'] == prov ]
  df_plot['Produksi'].plot(label = prov, figsize=(16,6)).legend()

# %%
df_new = dataset_explore
df_new.shape
# Out:
# (782, 2)

# %%
sample_provinces = provinsi[:3]
for prov in sample_provinces:
  df_plot = df_new.loc[df_new['Provinsi'] == prov ]
  df_plot['Produksi: 3 Years Mean'] = df_plot['Produksi'].rolling(window=4).mean()
  df_plot[['Produksi','Produksi: 3 Years Mean']].plot(title=prov, figsize=(16,6))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Optional specify a minimum number of periods
for prov in provinsi:
  df_plot = df_new.loc[df_new['Provinsi'] == prov ]
  df_plot['Produksi'].expanding(min_periods=1).mean().plot(label = prov, figsize=(16,6)).legend()

# %% [markdown]
# ##MODELING

# %%
dataset_prov =pd.read_csv('/content/'+filename, index_col="Tahun")
df_prov = dataset_prov
df_prov.head()
# Out:
#        Produksi
# Tahun
# 1993    1299699
# 1994    1329536
# 1995    1368074
# 1996    1419128
# 1997    1382905

# %%
import matplotlib.pyplot as plt # this is used for the plot the graph 
df_prov.plot()

# %%
from sklearn.model_selection import train_test_split

# %%
num_samples = df_prov.shape[0]
separator = int(num_samples * 0.6)
train = df_prov[:separator]
test = df_prov[separator:]

print(train.shape, test.shape)
print(train.shape, test.shape)
# Out:
# (13, 1) (10, 1)
# (13, 1) (10, 1)

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
sc.fit(train)
sc.fit(test)
# Out:
# MinMaxScaler()

# %%
scaled_train = sc.transform(train)
scaled_test = sc.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
# How many record to take into account
n_input = 3
n_features = 1
batch_size= 5

# %%
generator_train = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=batch_size)
generator_test = TimeseriesGenerator(scaled_test, scaled_test, length=n_input, batch_size=batch_size)

# %%
#Building the RNN
#Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
# model = Sequential()
# model.add(SimpleRNN(100, activation='relu', input_shape=(n_input, n_features)))
# model.add(Dense(8, activation="relu")) 
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='rmsprop')
# model.summary()

model = Sequential()
model.add(SimpleRNN(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 100)               10200
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 10,301
# Trainable params: 10,301
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
epochs = 100
history = model.fit_generator(generator_train, epochs=epochs, verbose=2, validation_data=generator_test)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 2/2 - 2s - loss: 0.0164 - val_loss: 0.3911 - 2s/epoch - 787ms/step
# Epoch 2/100
# 2/2 - 0s - loss: 0.0127 - val_loss: 0.3385 - 116ms/epoch - 58ms/step
# Epoch 3/100
# 2/2 - 0s - loss: 0.0087 - val_loss: 0.2869 - 104ms/epoch - 52ms/step
# Epoch 4/100
# 2/2 - 0s - loss: 0.0064 - val_loss: 0.2497 - 98ms/epoch - 49ms/step
# Epoch 5/100
# 2/2 - 0s - loss: 0.0068 - val_loss: 0.2286 - 122ms/epoch - 61ms/step
# Epoch 6/100
# 2/2 - 0s - loss: 0.0075 - val_loss: 0.2321 - 119ms/epoch - 60ms/step
# Epoch 7/100
# 2/2 - 0s - loss: 0.0060 - val_loss: 0.2464 - 117ms/epoch - 58ms/step
# Epoch 8/100
# 2/2 - 0s - loss: 0.0063 - val_loss: 0.2750 - 107ms/epoch - 54ms/step
# Epoch 9/100
# 2/2 - 0s - loss: 0.0052 - val_loss: 0.3054 - 149ms/epoch - 74ms/step
# Epoch 10/100
# 2/2 - 0s - loss: 0.0033 - val_loss: 0.3369 - 237ms/epoch - 119ms/step
# Epoch 11/100
# 2/2 - 0s - loss: 0.0038 - val_loss: 0.3727 - 225ms/epoch - 112ms/step
# Epoch 12/100
# 2/2 - 0s - loss: 0.0035 - val_loss: 0.3997 - 78ms/epoch - 39ms/step
# Epoch 13/100
# 2/2 - 0s - loss: 0.0035 - val_loss: 0.4267 - 63ms/epoch - 31ms/step
# Epoch 14/100
# 2/2 - 0s - loss: 0.0039 - val_loss: 0.4470 - 59ms/epoch - 29ms/step
# Epoch 15/100
# 2/2 - 0s - loss: 0.0025 - val_loss: 0.4617 - 63ms/epoch - 32ms/step
# Epoch 16/100
# 2/2 - 0s - loss: 0.0021 - val_loss: 0.4799 - 64ms/epoch - 32ms/step
# Epoch 17/100
# 2/2 - 0s - loss: 0.0036 - val_loss: 0.4916 - 63ms/epoch - 31ms/step
# Epoch 18/100
# 2/2 - 0s - loss: 0.0024 - val_loss: 0.5008 - 61ms/epoch - 31ms/step
# Epoch 19/100
# 2/2 - 0s - loss: 0.0021 - val_loss: 0.5102 - 60ms/epoch - 30ms/step
# Epoch 20/100
# 2/2 - 0s - loss: 0.0024 - val_loss: 0.5181 - 71ms/epoch - 35ms/step
# Epoch 21/100
# 2/2 - 0s - loss: 0.0017 - val_loss: 0.5294 - 61ms/epoch - 31ms/step
# Epoch 22/100
# 2/2 - 0s - loss: 0.0018 - val_loss: 0.5398 - 62ms/epoch - 31ms/step
# Epoch 23/100
# 2/2 - 0s - loss: 0.0018 - val_loss: 0.5463 - 61ms/epoch - 30ms/step
# Epoch 24/100
# 2/2 - 0s - loss: 0.0019 - val_loss: 0.5420 - 61ms/epoch - 31ms/step
# Epoch 25/100
# 2/2 - 0s - loss: 0.0025 - val_loss: 0.5330 - 62ms/epoch - 31ms/step
# Epoch 26/100
# 2/2 - 0s - loss: 0.0020 - val_loss: 0.5322 - 71ms/epoch - 36ms/step
# Epoch 27/100
# 2/2 - 0s - loss: 0.0018 - val_loss: 0.5354 - 67ms/epoch - 34ms/step
# Epoch 28/100
# 2/2 - 0s - loss: 0.0016 - val_loss: 0.5462 - 66ms/epoch - 33ms/step
# Epoch 29/100
# 2/2 - 0s - loss: 0.0019 - val_loss: 0.5560 - 61ms/epoch - 30ms/step
# Epoch 30/100
# 2/2 - 0s - loss: 0.0014 - val_loss: 0.5645 - 60ms/epoch - 30ms/step
# Epoch 31/100
# 2/2 - 0s - loss: 0.0012 - val_loss: 0.5714 - 63ms/epoch - 32ms/step
# Epoch 32/100
# 2/2 - 0s - loss: 0.0014 - val_loss: 0.5737 - 59ms/epoch - 30ms/step
# Epoch 33/100
# 2/2 - 0s - loss: 0.0012 - val_loss: 0.5812 - 60ms/epoch - 30ms/step
# Epoch 34/100
# 2/2 - 0s - loss: 0.0012 - val_loss: 0.5924 - 70ms/epoch - 35ms/step
# Epoch 35/100
# 2/2 - 0s - loss: 0.0017 - val_loss: 0.5987 - 63ms/epoch - 32ms/step
# Epoch 36/100
# 2/2 - 0s - loss: 0.0013 - val_loss: 0.5887 - 75ms/epoch - 38ms/step
# Epoch 37/100
# 2/2 - 0s - loss: 0.0015 - val_loss: 0.5794 - 67ms/epoch - 33ms/step
# Epoch 38/100
# 2/2 - 0s - loss: 0.0017 - val_loss: 0.5756 - 64ms/epoch - 32ms/step
# Epoch 39/100
# 2/2 - 0s - loss: 0.0012 - val_loss: 0.5712 - 59ms/epoch - 30ms/step
# Epoch 40/100
# 2/2 - 0s - loss: 0.0013 - val_loss: 0.5640 - 60ms/epoch - 30ms/step
# Epoch 41/100
# 2/2 - 0s - loss: 0.0011 - val_loss: 0.5630 - 67ms/epoch - 34ms/step
# Epoch 42/100
# 2/2 - 0s - loss: 0.0013 - val_loss: 0.5634 - 66ms/epoch - 33ms/step
# Epoch 43/100
# 2/2 - 0s - loss: 8.2169e-04 - val_loss: 0.5643 - 66ms/epoch - 33ms/step
# Epoch 44/100
# 2/2 - 0s - loss: 0.0011 - val_loss: 0.5689 - 66ms/epoch - 33ms/step
# Epoch 45/100
# 2/2 - 0s - loss: 0.0011 - val_loss: 0.5722 - 62ms/epoch - 31ms/step
# Epoch 46/100
# 2/2 - 0s - loss: 7.3445e-04 - val_loss: 0.5777 - 62ms/epoch - 31ms/step
# Epoch 47/100
# 2/2 - 0s - loss: 8.6780e-04 - val_loss: 0.5814 - 61ms/epoch - 30ms/step
# Epoch 48/100
# 2/2 - 0s - loss: 7.9909e-04 - val_loss: 0.5860 - 62ms/epoch - 31ms/step
# Epoch 49/100
# 2/2 - 0s - loss: 0.0012 - val_loss: 0.5832 - 67ms/epoch - 34ms/step
# Epoch 50/100
# 2/2 - 0s - loss: 9.0442e-04 - val_loss: 0.5816 - 61ms/epoch - 31ms/step
# Epoch 51/100
# 2/2 - 0s - loss: 0.0010 - val_loss: 0.5851 - 64ms/epoch - 32ms/step
# Epoch 52/100
# 2/2 - 0s - loss: 7.2377e-04 - val_loss: 0.5887 - 70ms/epoch - 35ms/step
# Epoch 53/100
# 2/2 - 0s - loss: 0.0013 - val_loss: 0.5917 - 62ms/epoch - 31ms/step
# Epoch 54/100
# 2/2 - 0s - loss: 0.0014 - val_loss: 0.5889 - 60ms/epoch - 30ms/step
# Epoch 55/100
# 2/2 - 0s - loss: 9.5771e-04 - val_loss: 0.5891 - 67ms/epoch - 33ms/step
# Epoch 56/100
# 2/2 - 0s - loss: 7.1265e-04 - val_loss: 0.5866 - 61ms/epoch - 30ms/step
# Epoch 57/100
# 2/2 - 0s - loss: 6.9887e-04 - val_loss: 0.5794 - 77ms/epoch - 39ms/step
# Epoch 58/100
# 2/2 - 0s - loss: 6.5422e-04 - val_loss: 0.5749 - 61ms/epoch - 30ms/step
# Epoch 59/100
# 2/2 - 0s - loss: 5.8376e-04 - val_loss: 0.5703 - 64ms/epoch - 32ms/step
# Epoch 60/100
# 2/2 - 0s - loss: 0.0013 - val_loss: 0.5697 - 79ms/epoch - 39ms/step
# Epoch 61/100
# 2/2 - 0s - loss: 7.6886e-04 - val_loss: 0.5664 - 69ms/epoch - 35ms/step
# Epoch 62/100
# 2/2 - 0s - loss: 6.5104e-04 - val_loss: 0.5615 - 62ms/epoch - 31ms/step
# Epoch 63/100
# 2/2 - 0s - loss: 9.3659e-04 - val_loss: 0.5647 - 60ms/epoch - 30ms/step
# Epoch 64/100
# 2/2 - 0s - loss: 8.2809e-04 - val_loss: 0.5745 - 62ms/epoch - 31ms/step
# Epoch 65/100
# 2/2 - 0s - loss: 5.8764e-04 - val_loss: 0.5818 - 61ms/epoch - 30ms/step
# Epoch 66/100
# 2/2 - 0s - loss: 8.9555e-04 - val_loss: 0.5911 - 68ms/epoch - 34ms/step
# Epoch 67/100
# 2/2 - 0s - loss: 5.1503e-04 - val_loss: 0.6000 - 61ms/epoch - 31ms/step
# Epoch 68/100
# 2/2 - 0s - loss: 0.0013 - val_loss: 0.5866 - 72ms/epoch - 36ms/step
# Epoch 69/100
# 2/2 - 0s - loss: 8.0395e-04 - val_loss: 0.5799 - 59ms/epoch - 30ms/step
# Epoch 70/100
# 2/2 - 0s - loss: 7.2982e-04 - val_loss: 0.5891 - 62ms/epoch - 31ms/step
# Epoch 71/100
# 2/2 - 0s - loss: 4.6097e-04 - val_loss: 0.5945 - 86ms/epoch - 43ms/step
# Epoch 72/100
# 2/2 - 0s - loss: 6.2880e-04 - val_loss: 0.6006 - 64ms/epoch - 32ms/step
# Epoch 73/100
# 2/2 - 0s - loss: 3.7775e-04 - val_loss: 0.6199 - 70ms/epoch - 35ms/step
# Epoch 74/100
# 2/2 - 0s - loss: 8.6689e-04 - val_loss: 0.6441 - 67ms/epoch - 33ms/step
# Epoch 75/100
# 2/2 - 0s - loss: 6.8979e-04 - val_loss: 0.6533 - 64ms/epoch - 32ms/step
# Epoch 76/100
# 2/2 - 0s - loss: 6.3039e-04 - val_loss: 0.6579 - 62ms/epoch - 31ms/step
# Epoch 77/100
# 2/2 - 0s - loss: 3.7896e-04 - val_loss: 0.6556 - 72ms/epoch - 36ms/step
# Epoch 78/100
# 2/2 - 0s - loss: 7.7514e-04 - val_loss: 0.6646 - 60ms/epoch - 30ms/step
# Epoch 79/100
# 2/2 - 0s - loss: 7.9332e-04 - val_loss: 0.6835 - 65ms/epoch - 32ms/step
# Epoch 80/100
# 2/2 - 0s - loss: 8.6823e-04 - val_loss: 0.6884 - 59ms/epoch - 30ms/step
# Epoch 81/100
# 2/2 - 0s - loss: 7.1332e-04 - val_loss: 0.6693 - 63ms/epoch - 31ms/step
# Epoch 82/100
# 2/2 - 0s - loss: 7.1112e-04 - val_loss: 0.6417 - 61ms/epoch - 31ms/step
# Epoch 83/100
# 2/2 - 0s - loss: 4.4573e-04 - val_loss: 0.6229 - 67ms/epoch - 34ms/step
# Epoch 84/100
# 2/2 - 0s - loss: 9.5178e-04 - val_loss: 0.6256 - 61ms/epoch - 30ms/step
# Epoch 85/100
# 2/2 - 0s - loss: 4.9950e-04 - val_loss: 0.6413 - 69ms/epoch - 34ms/step
# Epoch 86/100
# 2/2 - 0s - loss: 3.4675e-04 - val_loss: 0.6637 - 58ms/epoch - 29ms/step
# Epoch 87/100
# 2/2 - 0s - loss: 5.0619e-04 - val_loss: 0.6745 - 62ms/epoch - 31ms/step
# Epoch 88/100
# 2/2 - 0s - loss: 0.0011 - val_loss: 0.6528 - 60ms/epoch - 30ms/step
# Epoch 89/100
# 2/2 - 0s - loss: 5.2670e-04 - val_loss: 0.6229 - 60ms/epoch - 30ms/step
# Epoch 90/100
# 2/2 - 0s - loss: 6.2093e-04 - val_loss: 0.6101 - 61ms/epoch - 30ms/step
# Epoch 91/100
# 2/2 - 0s - loss: 6.3532e-04 - val_loss: 0.6177 - 59ms/epoch - 29ms/step
# Epoch 92/100
# 2/2 - 0s - loss: 5.5590e-04 - val_loss: 0.6472 - 69ms/epoch - 34ms/step
# Epoch 93/100
# 2/2 - 0s - loss: 3.9303e-04 - val_loss: 0.6677 - 58ms/epoch - 29ms/step
# Epoch 94/100
# 2/2 - 0s - loss: 0.0010 - val_loss: 0.6613 - 58ms/epoch - 29ms/step
# Epoch 95/100
# 2/2 - 0s - loss: 6.1896e-04 - val_loss: 0.6392 - 63ms/epoch - 32ms/step
# Epoch 96/100
# 2/2 - 0s - loss: 5.3247e-04 - val_loss: 0.6139 - 61ms/epoch - 30ms/step
# Epoch 97/100
# 2/2 - 0s - loss: 5.0954e-04 - val_loss: 0.6062 - 59ms/epoch - 29ms/step
# Epoch 98/100
# 2/2 - 0s - loss: 4.9185e-04 - val_loss: 0.6184 - 60ms/epoch - 30ms/step
# Epoch 99/100
# 2/2 - 0s - loss: 4.7778e-04 - val_loss: 0.6396 - 65ms/epoch - 33ms/step
# Epoch 100/100
# 2/2 - 0s - loss: 3.3596e-04 - val_loss: 0.6642 - 60ms/epoch - 30ms/step

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
prediction_result = []

test_batches = scaled_train[-n_input:]
reshaping_batches = test_batches.reshape((1, n_input, n_features))

# %%
import numpy as np
for i in range(len(test)):
    predicted_output = model.predict(reshaping_batches )[0]
    prediction_result.append(predicted_output) 
    reshaping_batches = np.append(reshaping_batches [:,1:,:],[[predicted_output]],axis=1)

# %%
prediction_result
# Out:
# [array([-0.22951798], dtype=float32),
#  array([-0.1203025], dtype=float32),
#  array([0.27205637], dtype=float32),
#  array([0.31147078], dtype=float32),
#  array([0.05624197], dtype=float32),
#  array([-0.35927555], dtype=float32),
#  array([-0.17701034], dtype=float32),
#  array([0.35814157], dtype=float32),
#  array([0.41976702], dtype=float32),
#  array([0.05739452], dtype=float32)]

# %%
actual_values = sc.inverse_transform(prediction_result)
print(actual_values.shape)
test['Predictions'] = actual_values
test.plot(figsize=(16,6))
# Out:
# (10, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# calculate RMSE
from sklearn.metrics import mean_squared_error,r2_score
results = np.array(prediction_result).squeeze()
scaled_test = np.array(scaled_test).squeeze()

mse = mean_squared_error(scaled_test, results)
rmse = np.sqrt(mean_squared_error(scaled_test, results))
print('Test MSE: %.3f' % mse)
print('Test RMSE: %.3f' % rmse)
# print('R2 Score: %.3f' % r2)
# Out:
# Test MSE: 0.221
# Test RMSE: 0.470
